# %%
# leitura dos dados
import pandas as pd
pd.set_option('future.no_silent_downcasting', True)

from pandas.api.types import CategoricalDtype
from sentence_transformers import SentenceTransformer
from tqdm import tqdm

# funções + embeddings
from src.categorizador_batch import categorizar_coluna_batch, preparar_para_categoria

# mapeamentos
from src.categorizar_texto import (
    mapeamento_motivo_fluencia,
    mapeamento_profissoes,
    mapeamento_paises,
    mapeamento_estados,
    mapeamento_outros_idiomas,
    mapeamento_problema_aprender,
    expandir_mapeamento
)

# dados brutos
df_pesquisa_alunos_l3_24 = pd.read_csv(r"C:\Users\Camilo_Bica\data_science\consultoria\portal_vhe\dados\[L3-24] [DSE] Pesquisa Novos alunos.csv")
df_pesquisa_alunos_l4_24 = pd.read_csv(r"C:\Users\Camilo_Bica\data_science\consultoria\portal_vhe\dados\[L4-24] [DSE] Pesquisa Novos alunos.csv")
df_pesquisa_alunos_l1_25 = pd.read_csv(r"C:\Users\Camilo_Bica\data_science\consultoria\portal_vhe\dados\[L1-25] [VOE] Pesquisa Novos alunos_A.csv")

# %%
df_pesquisa_alunos_l3_24 = df_pesquisa_alunos_l3_24.drop([
    "Nome", 
    "Caso tenha alguma deficiência, transtorno ou necessidade especial que acredite ser importante que nós saibamos para melhor atendê-lo, descreva-a aqui, por favor:",
    "Qual foi a sua principal dúvida que você tinha antes de entrar no Portal VHE?",
    "De todos os recursos do Portal VHE, qual deles mais te motivou a entrar? (Pode marcar mais de uma)"
], axis=1, errors='ignore')

df_pesquisa_alunos_l4_24 = df_pesquisa_alunos_l4_24.drop([
    "Nome", 
    "Caso tenha alguma deficiência, transtorno ou necessidade especial que acredite ser importante que nós saibamos para melhor atendê-lo, descreva-a aqui, por favor:",
    "Qual foi a sua principal dúvida que você tinha antes de entrar no Portal VHE?",
    "De todos os recursos do Portal VHE, qual deles mais te motivou a entrar? (Pode marcar mais de uma)"
], axis=1, errors='ignore')

df_pesquisa_alunos_l1_25 = df_pesquisa_alunos_l1_25.drop([
    "Caso tenha alguma deficiência, transtorno ou necessidade especial que acredite ser importante que nós saibamos para melhor atendê-lo, descreva-a aqui, por favor:",
    "De todos os recursos do Portal VHE, qual deles mais te motivou a entrar? (Pode marcar mais de uma)",
    "Qual foi a sua principal dúvida que você tinha antes de entrar no Portal VHE? Por onde começar e se deveria dar o primeiro passo pra fazer o curso."
], axis=1, errors='ignore')

# %%
df_pesquisa_alunos_l3_24.rename(columns={
    'Carimbo de data/hora': 'data_inscricao',
    'Nome de usuário': 'email',
    'Data de Nascimento': 'data_nascimento',
    'Qual a sua Profissão?': 'profissao',
    'Gênero': 'genero',
    'Sua faixa etária': 'faixa_etaria',
    'Qual o seu nível de escolaridade?': 'escolaridade',
    'Em que país você reside atualmente?': 'pais',
    'Em que estado/província você reside atualmente?': 'estado',
    'Sua renda média?': 'renda_media',
    'Como você adquiriu o Portal VHE? (não se preocupe, esses dados não serão divulgados)': 'como_comprou_portal',
    'Há quanto tempo você me conhecia antes de entrar para o Portal?': 'tempo_antes_portal',
    'Por ONDE você mais acompanha meu conteúdo?': 'onde_acompanha_conteudo',
    'Qual o seu nível no idioma?': 'nivel_idioma',
    'Você fala outro idioma?': 'fala_outro_idioma',
    'Por que você quer ser fluente em Espanhol? ': 'motivo_fluencia_espanhol',
    'E qual problema mais te motivou a entrar no Portal VHE em busca da solução? ': 'problema_aprender',
    'Você tem interesse em garantir mais 1 ano de acesso ao Portal VHE com 50% de desconto? Caso sim, marque abaixo e nossa equipe vai falar com você. ': 'interesse_renovacao_portal'
}, inplace=True)

# %%
df_pesquisa_alunos_l4_24.rename(columns={
    'Carimbo de data/hora': 'data_inscricao',
    'Nome de usuário': 'email',
    'Data de Nascimento': 'data_nascimento',
    'Qual a sua Profissão?': 'profissao',
    'Gênero': 'genero',
    'Sua faixa etária': 'faixa_etaria',
    'Qual o seu nível de escolaridade?': 'escolaridade',
    'Em que país você reside atualmente?': 'pais',
    'Em que estado/província você reside atualmente?': 'estado',
    'Sua renda média?': 'renda_media',
    'Como você adquiriu o Portal VHE? (não se preocupe, esses dados não serão divulgados)': 'como_comprou_portal',
    'Há quanto tempo você me conhecia antes de entrar para o Portal?': 'tempo_antes_portal',
    'Por ONDE você mais acompanha meu conteúdo?': 'onde_acompanha_conteudo',
    'Qual o seu nível no idioma?': 'nivel_idioma',
    'Você fala outro idioma?': 'fala_outro_idioma',
    'Por que você quer ser fluente em Espanhol? ': 'motivo_fluencia_espanhol',
    'E qual problema mais te motivou a entrar no Portal VHE em busca da solução? ': 'problema_aprender',
    'Você tem interesse em garantir mais 1 ano de acesso ao Portal VHE com 50% de desconto? Caso sim, marque abaixo e nossa equipe vai falar com você. ': 'interesse_renovacao_portal'
}, inplace=True)

# %%
df_pesquisa_alunos_l1_25.rename(columns={
    'Carimbo de data/hora': 'data_inscricao',
    'Nome de usuário': 'email',
    'Data de nascimento: 14/12/1987': 'data_nascimento',
    'Profissão: Analista Financeira': 'profissao',
    'Gênero': 'genero',
    'Sua faixa etária': 'faixa_etaria',
    'Qual o seu nível de escolaridade?': 'escolaridade',
    'Em que país você reside atualmente?  Brasil ': 'pais',
    'Em que estado/província você reside atualmente?  São Paulo/SP': 'estado',
    'Sua renda média?': 'renda_media',
    'Como você adquiriu o Portal VHE? (não se preocupe, esses dados não serão divulgados)': 'como_comprou_portal',
    'Há quanto tempo você me conhecia antes de entrar para o Portal?': 'tempo_antes_portal',
    'Por ONDE você mais acompanha meu conteúdo?': 'onde_acompanha_conteudo',
    'Qual o seu nível no idioma?': 'nivel_idioma',
    'Você fala outro idioma?': 'fala_outro_idioma',
    'Por que você quer ser fluente em Espanhol? ': 'motivo_fluencia_espanhol',
    'E qual problema mais te motivou a entrar no Portal VHE em busca da solução? ': 'problema_aprender',
}, inplace=True)

# %%
df_total = [
    df_pesquisa_alunos_l3_24,
    df_pesquisa_alunos_l4_24,
    df_pesquisa_alunos_l1_25
]

nomes = [
    "df_pesquisa_alunos_l3_24",
    "df_pesquisa_alunos_l4_24",
    "df_pesquisa_alunos_l1_25"
]

for nome, df in zip(nomes, df_total):
    print(f"\n=== {nome} ===")
    df.info()
# Out:
# === df_pesquisa_alunos_l3_24 ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292 entries, 0 to 291
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   data_inscricao              292 non-null    object
#  1   email                       292 non-null    object
#  2   data_nascimento             292 non-null    object
#  3   profissao                   292 non-null    object
#  4   genero                      292 non-null    object
#  5   faixa_etaria                292 non-null    object
#  6   escolaridade                292 non-null    object
#  7   pais                        292 non-null    object
#  8   estado                      292 non-null    object
#  9   renda_media                 292 non-null    object
#  10  como_comprou_portal         292 non-null    object
#  11  tempo_antes_portal          292 non-null    object
#  12  onde_acompanha_conteudo     292 non-null    object
#  13  nivel_idioma                292 non-null    object
#  14  fala_outro_idioma           292 non-null    object
#  15  motivo_fluencia_espanhol    292 non-null    object
#  16  problema_aprender           292 non-null    object
#  17  interesse_renovacao_portal  292 non-null    object
# dtypes: object(18)
# memory usage: 41.2+ KB
#
# === df_pesquisa_alunos_l4_24 ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 295 entries, 0 to 294
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   data_inscricao              295 non-null    object
#  1   email                       295 non-null    object
#  2   data_nascimento             295 non-null    object
#  3   profissao                   295 non-null    object
#  4   genero                      295 non-null    object
#  5   faixa_etaria                295 non-null    object
#  6   escolaridade                295 non-null    object
#  7   pais                        295 non-null    object
#  8   estado                      295 non-null    object
#  9   renda_media                 295 non-null    object
#  10  como_comprou_portal         295 non-null    object
#  11  tempo_antes_portal          295 non-null    object
#  12  onde_acompanha_conteudo     295 non-null    object
#  13  nivel_idioma                295 non-null    object
#  14  fala_outro_idioma           295 non-null    object
#  15  motivo_fluencia_espanhol    295 non-null    object
#  16  problema_aprender           295 non-null    object
#  17  interesse_renovacao_portal  295 non-null    object
# dtypes: object(18)
# memory usage: 41.6+ KB
#
# === df_pesquisa_alunos_l1_25 ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   data_inscricao                  34 non-null     object
#  1   email                           34 non-null     object
#  2   data_nascimento                 34 non-null     object
#  3   profissao                       34 non-null     object
#  4   Nome: Marília Carvalho Martins  34 non-null     object
#  5   genero                          34 non-null     object
#  6   faixa_etaria                    34 non-null     object
#  7   escolaridade                    34 non-null     object
#  8   pais                            34 non-null     object
#  9   estado                          34 non-null     object
#  10  renda_media                     34 non-null     object
#  11  como_comprou_portal             34 non-null     object
#  12  tempo_antes_portal              34 non-null     object
#  13  onde_acompanha_conteudo         34 non-null     object
#  14  nivel_idioma                    34 non-null     object
#  15  fala_outro_idioma               34 non-null     object
#  16  motivo_fluencia_espanhol        34 non-null     object
#  17  problema_aprender               34 non-null     object
# dtypes: object(18)
# memory usage: 4.9+ KB

# %%
for df in df_total:
    df['data_nascimento'] = pd.to_datetime(df['data_nascimento'], errors='coerce')
    df['data_inscricao'] = pd.to_datetime(
        df['data_inscricao'].str.replace(' GMT-3', '', regex=False),
        format='%Y/%m/%d %I:%M:%S %p',
        errors='coerce'
    ).dt.normalize()

# %%
for nome, df in zip(nomes, df_total):
    print(f"\n=== {nome} ===")
    df.info()
# Out:
# === df_pesquisa_alunos_l3_24 ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292 entries, 0 to 291
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   data_inscricao              292 non-null    datetime64[ns]
#  1   email                       292 non-null    object
#  2   data_nascimento             291 non-null    datetime64[ns]
#  3   profissao                   292 non-null    object
#  4   genero                      292 non-null    object
#  5   faixa_etaria                292 non-null    object
#  6   escolaridade                292 non-null    object
#  7   pais                        292 non-null    object
#  8   estado                      292 non-null    object
#  9   renda_media                 292 non-null    object
#  10  como_comprou_portal         292 non-null    object
#  11  tempo_antes_portal          292 non-null    object
#  12  onde_acompanha_conteudo     292 non-null    object
#  13  nivel_idioma                292 non-null    object
#  14  fala_outro_idioma           292 non-null    object
#  15  motivo_fluencia_espanhol    292 non-null    object
#  16  problema_aprender           292 non-null    object
#  17  interesse_renovacao_portal  292 non-null    object
# dtypes: datetime64[ns](2), object(16)
# memory usage: 41.2+ KB
#
# === df_pesquisa_alunos_l4_24 ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 295 entries, 0 to 294
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   data_inscricao              295 non-null    datetime64[ns]
#  1   email                       295 non-null    object
#  2   data_nascimento             292 non-null    datetime64[ns]
#  3   profissao                   295 non-null    object
#  4   genero                      295 non-null    object
#  5   faixa_etaria                295 non-null    object
#  6   escolaridade                295 non-null    object
#  7   pais                        295 non-null    object
#  8   estado                      295 non-null    object
#  9   renda_media                 295 non-null    object
#  10  como_comprou_portal         295 non-null    object
#  11  tempo_antes_portal          295 non-null    object
#  12  onde_acompanha_conteudo     295 non-null    object
#  13  nivel_idioma                295 non-null    object
#  14  fala_outro_idioma           295 non-null    object
#  15  motivo_fluencia_espanhol    295 non-null    object
#  16  problema_aprender           295 non-null    object
#  17  interesse_renovacao_portal  295 non-null    object
# dtypes: datetime64[ns](2), object(16)
# memory usage: 41.6+ KB
#
# === df_pesquisa_alunos_l1_25 ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   data_inscricao                  34 non-null     datetime64[ns]
#  1   email                           34 non-null     object
#  2   data_nascimento                 33 non-null     datetime64[ns]
#  3   profissao                       34 non-null     object
#  4   Nome: Marília Carvalho Martins  34 non-null     object
#  5   genero                          34 non-null     object
#  6   faixa_etaria                    34 non-null     object
#  7   escolaridade                    34 non-null     object
#  8   pais                            34 non-null     object
#  9   estado                          34 non-null     object
#  10  renda_media                     34 non-null     object
#  11  como_comprou_portal             34 non-null     object
#  12  tempo_antes_portal              34 non-null     object
#  13  onde_acompanha_conteudo         34 non-null     object
#  14  nivel_idioma                    34 non-null     object
#  15  fala_outro_idioma               34 non-null     object
#  16  motivo_fluencia_espanhol        34 non-null     object
#  17  problema_aprender               34 non-null     object
# dtypes: datetime64[ns](2), object(16)
# memory usage: 4.9+ KB

# %%
for nome, df in zip(nomes, df_total):
    print(f"\n=== {nome} ===")
    display(df.head())
# Out:
# === df_pesquisa_alunos_l3_24 ===
#   data_inscricao                      email data_nascimento  \
# 0     2024-05-14  teofilotavares@icloud.com      1983-01-06
# 1     2024-05-16   leosantanati@outlook.com      1995-07-16
# 2     2024-05-16   flaviojatoba@outlook.com      1992-10-28
# 3     2024-05-17  alandematos10@hotmail.com      1982-05-08
# 4     2024-05-17  alandematos10@hotmail.com      1982-05-08
#
#                profissao     genero faixa_etaria            escolaridade  \
# 0     Médico Veterinário  Masculino      35 - 44  Pós-graduação completa
# 1               Autônomo  Masculino      25 - 34          Médio completo
# 2      Relações Públicas  Masculino      25 - 34       Superior completo
# 3  Motorista socorrista   Masculino      35 - 44       Superior completo
# 4            Enfermeiro   Masculino      35 - 44       Superior completo
#
#      pais     estado                 renda_media  \
# 0  Brasil      Goiás            Mais de R$10.000
# 1  Brasil  São Paulo  De R$2.500,01 à R$5.000,00
# 2  Brasil  São Paulo  De R$2.500,01 à R$5.000,00
# 3  Brasil         MG  De R$1.500,01 à R$2.500,00
# 4  Brasil         MG  De R$1.500,01 à R$2.500,00
#
#                   como_comprou_portal                    tempo_antes_portal  \
# 0  Comprei com o meu próprio dinheiro  Há mais de um mês e menos de 3 meses
# 1  Comprei com o meu próprio dinheiro     Conheci durante o evento gratuito
# 2  Comprei com o meu próprio dinheiro     Conheci durante o evento gratuito
# 3  Comprei com o meu próprio dinheiro     Conheci durante o evento gratuito
# 4  Comprei com o meu próprio dinheiro     Conheci durante o evento gratuito
#
#   onde_acompanha_conteudo                                       nivel_idioma  \
# 0                 YouTube  Iniciante — dando os primeiros passos e vou me...
# 1                 YouTube  Iniciante — dando os primeiros passos e vou me...
# 2         Não acompanhava  Iniciante — dando os primeiros passos e vou me...
# 3                 YouTube  Iniciante — dando os primeiros passos e vou me...
# 4                 YouTube  Iniciante — dando os primeiros passos e vou me...
#
#                                    fala_outro_idioma  \
# 0  Não, espanhol será meu primeiro idioma estrang...
# 1  Não, espanhol será meu primeiro idioma estrang...
# 2  Não, espanhol será meu primeiro idioma estrang...
# 3  Não, espanhol será meu primeiro idioma estrang...
# 4  Não, espanhol será meu primeiro idioma estrang...
#
#                             motivo_fluencia_espanhol  \
# 0  Quero viajar e viver experiências marcantes me...
# 1                                  Morar no exterior
# 2                                  Morar no exterior
# 3                         Estou indo fazer Medicina
# 4                      Quero estudar fora do Brasil
#
#                                    problema_aprender  \
# 0               Não tenho tempo de sobra pra estudar
# 1  Não tenho disciplina, não consigo estudar sem ...
# 2  Não tenho disciplina, não consigo estudar sem ...
# 3                 Não sei por onde começar a estudar
# 4                       Falta de um método eficiente
#
#                           interesse_renovacao_portal
# 0                                      Não, obrigado
# 1                                      Não, obrigado
# 2                                      Não, obrigado
# 3  Sim, eu quero ter mais tranquilidade para estu...
# 4                                      Não, obrigado
# === df_pesquisa_alunos_l4_24 ===
#   data_inscricao                            email data_nascimento  \
# 0     2024-08-02                 18esms@gmail.com      1992-09-18
# 1     2024-08-02           t.rozafontes@gmail.com      1959-06-07
# 2     2024-08-05        danycapereira@hotmail.com      1981-07-30
# 3     2024-08-05  isabelclaudio.claudio@gmail.com      1960-09-18
# 4     2024-08-05          rose.mlima@yahoo.com.br      1959-06-14
#
#                            profissao     genero faixa_etaria  \
# 0                     ADMINISTRADORA   Feminino      25 - 34
# 1        funcionário público federal  Masculino          +55
# 2            Relações  Trabalhistas    Feminino      35 - 44
# 3                         Aposentada   Feminino          +55
# 4  Técnica de informática aposentada   Feminino          +55
#
#              escolaridade     pais           estado  \
# 0  Pós-graduação completa   BRASIL        SÃO PAULO
# 1  Pós-graduação completa   Brasil               RJ
# 2       Superior completo   Brasil   Rio de Janeiro
# 3  Pós-graduação completa  Brasil   Rio de Janeiro
# 4     Superior incompleto   Brasil        Recife PE
#
#                   renda_media                 como_comprou_portal  \
# 0       De R$5.000 a R$10.000  Comprei com o meu próprio dinheiro
# 1       De R$5.000 a R$10.000  Comprei com o meu próprio dinheiro
# 2  De R$2.500,01 à R$5.000,00  Comprei com o meu próprio dinheiro
# 3            Mais de R$10.000  Comprei com o meu próprio dinheiro
# 4  De R$2.500,01 à R$5.000,00  Comprei com o meu próprio dinheiro
#
#                      tempo_antes_portal onde_acompanha_conteudo  \
# 0     Conheci durante o evento gratuito                 YouTube
# 1  Há mais de um mês e menos de 3 meses                 YouTube
# 2     Conheci durante o evento gratuito                 YouTube
# 3  Há mais de um mês e menos de 3 meses                 YouTube
# 4  Há mais de um mês e menos de 3 meses                 YouTube
#
#                                         nivel_idioma  \
# 0               Perdido, mas estou motivado a mudar!
# 1  Iniciante — dando os primeiros passos e vou me...
# 2  Iniciante — dando os primeiros passos e vou me...
# 3  Intermediário — já entende muita coisa, mas te...
# 4  Iniciante — dando os primeiros passos e vou me...
#
#                                    fala_outro_idioma  \
# 0  Não, espanhol será meu primeiro idioma estrang...
# 1                                    POUCO DE INGLÊS
# 2  Não, espanhol será meu primeiro idioma estrang...
# 3  Não, espanhol será meu primeiro idioma estrang...
# 4  Não, espanhol será meu primeiro idioma estrang...
#
#                             motivo_fluencia_espanhol  \
# 0         Gosto do idioma e quero aprender por hobby
# 1                                  Morar no exterior
# 2         Conquistar um emprego melhor e ganhar mais
# 3  Quero viajar e viver experiências marcantes me...
# 4                                  Morar no exterior
#
#                                    problema_aprender  \
# 0  Não tenho disciplina, não consigo estudar sem ...
# 1                 Não sei por onde começar a estudar
# 2               Não tenho tempo de sobra pra estudar
# 3            Tenho muita dificuldade com a pronúncia
# 4                       Falta de um método eficiente
#
#                           interesse_renovacao_portal
# 0  Sim, eu quero ter mais tranquilidade para estu...
# 1                                      Não, obrigado
# 2                                      Não, obrigado
# 3                                      Não, obrigado
# 4                                      Não, obrigado
# === df_pesquisa_alunos_l1_25 ===
#   data_inscricao                        email data_nascimento  \
# 0     2025-01-09     mayssaamazonas@gmail.com      1998-02-03
# 1     2025-01-09              teste@teste.com      2025-01-30
# 2     2025-01-10   thalitachociay07@gmail.com      2003-08-07
# 3     2025-01-10  flaviamoreira1212@gmail.com      1997-09-12
# 4     2025-01-13      louzadoneto@hotmail.com      1975-03-01
#
#                              profissao     Nome: Marília Carvalho Martins  \
# 0             Extensionista de Cílios              Mayssa Alves Amazonas
# 1                                24242                              teste
# 2              Auxiliar administrativo  thalita vitória amaral dos santos
# 3                  Operadora de caixa                      FLÁVIA MOREIRA
# 4  Servidor Público do Estado da Bahia        Mário da Silva Louzado Neto
#
#       genero faixa_etaria            escolaridade    pais              estado  \
# 0   Feminino      25 - 34          Médio completo  Brasil  Mato Grosso do Sul
# 1  Masculino      18 - 24        Médio incompleto  424242               42424
# 2   Feminino      18 - 24     Superior incompleto  Brasil                  MT
# 3   Feminino      25 - 34          Médio completo  Brasil               Pará
# 4  Masculino      44 - 55  Pós-graduação completa  Brasil               Bahia
#
#                   renda_media                 como_comprou_portal  \
# 0  De R$1.500,01 à R$2.500,00  Comprei com o meu próprio dinheiro
# 1            Não tenho renda.                     Pedi emprestado
# 2  De R$2.500,01 à R$5.000,00  Comprei com o meu próprio dinheiro
# 3              Até R$1.500,00  Comprei com o meu próprio dinheiro
# 4       De R$5.000 a R$10.000  Comprei com o meu próprio dinheiro
#
#                   tempo_antes_portal onde_acompanha_conteudo  \
# 0   Mais de 3 meses e menos de 1 ano               Instagram
# 1   Mais de 3 meses e menos de 1 ano         Não acompanhava
# 2                      Mais de 1 ano               Instagram
# 3  Conheci durante o evento gratuito                 YouTube
# 4   Mais de 3 meses e menos de 1 ano                 YouTube
#
#                                         nivel_idioma  \
# 0  Iniciante — dando os primeiros passos e vou me...
# 1               Perdido, mas estou motivado a mudar!
# 2  Intermediário — já entende muita coisa, mas te...
# 3  Iniciante — dando os primeiros passos e vou me...
# 4               Perdido, mas estou motivado a mudar!
#
#                                    fala_outro_idioma  \
# 0  Não, espanhol será meu primeiro idioma estrang...
# 1                                        Sim, inglês
# 2  Não, espanhol será meu primeiro idioma estrang...
# 3  Não, espanhol será meu primeiro idioma estrang...
# 4  Não, espanhol será meu primeiro idioma estrang...
#
#                             motivo_fluencia_espanhol  \
# 0  Quero viajar e viver experiências marcantes me...
# 1         Gosto do idioma e quero aprender por hobby
# 2  Quero viajar e viver experiências marcantes me...
# 3         Conquistar um emprego melhor e ganhar mais
# 4  Quero viajar e viver experiências marcantes me...
#
#                                    problema_aprender
# 0                       Falta de um método eficiente
# 1            Tenho muita dificuldade com a pronúncia
# 2  Não tenho disciplina, não consigo estudar sem ...
# 3                 Não sei por onde começar a estudar
# 4                 Não sei por onde começar a estudar

# %%
# Adiciona a coluna de identificação dos lançamentos
df_pesquisa_alunos_l3_24['lancamentos'] = 'L3-24'
df_pesquisa_alunos_l4_24['lancamentos'] = 'L4-24'
df_pesquisa_alunos_l1_25['lancamentos'] = 'L1-25'

# %%
# Remover a coluna extra do df_l1
df_pesquisa_alunos_l1_25.drop(columns=['Nome: Marília Carvalho Martins'], inplace=True)

# Concatenar os dataframes
df_pesquisa_alunos_lancamentos = pd.concat([
    df_pesquisa_alunos_l3_24,
    df_pesquisa_alunos_l4_24,
    df_pesquisa_alunos_l1_25
], ignore_index=True).copy()

df_pesquisa_alunos_lancamentos
# Out:
#     data_inscricao                          email data_nascimento  \
# 0       2024-05-14      teofilotavares@icloud.com      1983-01-06
# 1       2024-05-16       leosantanati@outlook.com      1995-07-16
# 2       2024-05-16       flaviojatoba@outlook.com      1992-10-28
# 3       2024-05-17      alandematos10@hotmail.com      1982-05-08
# 4       2024-05-17      alandematos10@hotmail.com      1982-05-08
# ..             ...                            ...             ...
# 616     2025-01-27         joaofurtadon@gmail.com      1983-07-06
# 617     2025-01-27  moreirapriscilla@yahoo.com.br      1975-05-28
# 618     2025-01-27               bilam@uol.com.br      1982-12-02
# 619     2025-01-27        jurodrigues96@gmail.com      1996-08-16
# 620     2025-02-05      juninhocosta000@gmail.com             NaT
#
#                       profissao     genero faixa_etaria  \
# 0            Médico Veterinário  Masculino      35 - 44
# 1                      Autônomo  Masculino      25 - 34
# 2             Relações Públicas  Masculino      25 - 34
# 3         Motorista socorrista   Masculino      35 - 44
# 4                   Enfermeiro   Masculino      35 - 44
# ..                          ...        ...          ...
# 616                      medico  Masculino      35 - 44
# 617                   Psicóloga   Feminino      44 - 55
# 618        Funcionária pública    Feminino      35 - 44
# 619                    Cineasta   Feminino      25 - 34
# 620  Operador de Telemarketing   Masculino      25 - 34
#
#                escolaridade    pais              estado  \
# 0    Pós-graduação completa  Brasil               Goiás
# 1            Médio completo  Brasil           São Paulo
# 2         Superior completo  Brasil           São Paulo
# 3         Superior completo  Brasil                  MG
# 4         Superior completo  Brasil                  MG
# ..                      ...     ...                 ...
# 616  Pós-graduação completa  brasil            maranhao
# 617  Pós-graduação completa  Brasil  Rio de Janeiro, RJ
# 618  Pós-graduação completa  Brasil          São Paulo
# 619       Superior completo  Brasil      Rio de Janeiro
# 620          Médio completo  Brasil      Salvador/Bahia
#
#                     renda_media                  como_comprou_portal  \
# 0              Mais de R$10.000   Comprei com o meu próprio dinheiro
# 1    De R$2.500,01 à R$5.000,00   Comprei com o meu próprio dinheiro
# 2    De R$2.500,01 à R$5.000,00   Comprei com o meu próprio dinheiro
# 3    De R$1.500,01 à R$2.500,00   Comprei com o meu próprio dinheiro
# 4    De R$1.500,01 à R$2.500,00   Comprei com o meu próprio dinheiro
# ..                          ...                                  ...
# 616            Mais de R$10.000   Comprei com o meu próprio dinheiro
# 617            Mais de R$10.000   Comprei com o meu próprio dinheiro
# 618  De R$2.500,01 à R$5.000,00   Comprei com o meu próprio dinheiro
# 619  De R$1.500,01 à R$2.500,00  Meus pais (ou parentes) me ajudaram
# 620              Até R$1.500,00           Conheci através do Youtube
#
#                        tempo_antes_portal  \
# 0    Há mais de um mês e menos de 3 meses
# 1       Conheci durante o evento gratuito
# 2       Conheci durante o evento gratuito
# 3       Conheci durante o evento gratuito
# 4       Conheci durante o evento gratuito
# ..                                    ...
# 616     Conheci durante o evento gratuito
# 617  Há mais de um mês e menos de 3 meses
# 618     Conheci durante o evento gratuito
# 619  Há mais de um mês e menos de 3 meses
# 620       Conheci desde Dezembro de 2023.
#
#                         onde_acompanha_conteudo  \
# 0                                       YouTube
# 1                                       YouTube
# 2                               Não acompanhava
# 3                                       YouTube
# 4                                       YouTube
# ..                                          ...
# 616                                     YouTube
# 617                                   Instagram
# 618                                   Instagram
# 619                                   Instagram
# 620  Acompanho pelo Instagram, Youtube, TikTok.
#
#                                           nivel_idioma  \
# 0    Iniciante — dando os primeiros passos e vou me...
# 1    Iniciante — dando os primeiros passos e vou me...
# 2    Iniciante — dando os primeiros passos e vou me...
# 3    Iniciante — dando os primeiros passos e vou me...
# 4    Iniciante — dando os primeiros passos e vou me...
# ..                                                 ...
# 616  Iniciante — dando os primeiros passos e vou me...
# 617  Iniciante — dando os primeiros passos e vou me...
# 618  Intermediário — já entende muita coisa, mas te...
# 619  Intermediário — já entende muita coisa, mas te...
# 620  Me vejo como iniciante, já tive aulas intensiv...
#
#                                      fala_outro_idioma  \
# 0    Não, espanhol será meu primeiro idioma estrang...
# 1    Não, espanhol será meu primeiro idioma estrang...
# 2    Não, espanhol será meu primeiro idioma estrang...
# 3    Não, espanhol será meu primeiro idioma estrang...
# 4    Não, espanhol será meu primeiro idioma estrang...
# ..                                                 ...
# 616  Não, espanhol será meu primeiro idioma estrang...
# 617  Espanhol será o primeiro a ficar fluente. Ingl...
# 618  Não, espanhol será meu primeiro idioma estrang...
# 619                                        Sim, inglês
# 620          Além do espanhol, fiz um pouco de Inglês.
#
#                               motivo_fluencia_espanhol  \
# 0    Quero viajar e viver experiências marcantes me...
# 1                                    Morar no exterior
# 2                                    Morar no exterior
# 3                           Estou indo fazer Medicina
# 4                        Quero estudar fora do Brasil
# ..                                                 ...
# 616         Gosto do idioma e quero aprender por hobby
# 617  Quero viajar e viver experiências marcantes me...
# 618  Quero viajar e viver experiências marcantes me...
# 619                                        Intercâmbio
# 620                    Pra conseguir um emprego melhor
#
#                                      problema_aprender  \
# 0                 Não tenho tempo de sobra pra estudar
# 1    Não tenho disciplina, não consigo estudar sem ...
# 2    Não tenho disciplina, não consigo estudar sem ...
# 3                   Não sei por onde começar a estudar
# 4                         Falta de um método eficiente
# ..                                                 ...
# 616  Não tenho disciplina, não consigo estudar sem ...
# 617                 Não sei por onde começar a estudar
# 618  Não tenho disciplina, não consigo estudar sem ...
# 619  Entendo bem espanhol, mas não tenho estudo for...
# 620                       Falta de um método eficiente
#
#                             interesse_renovacao_portal lancamentos
# 0                                        Não, obrigado       L3-24
# 1                                        Não, obrigado       L3-24
# 2                                        Não, obrigado       L3-24
# 3    Sim, eu quero ter mais tranquilidade para estu...       L3-24
# 4                                        Não, obrigado       L3-24
# ..                                                 ...         ...
# 616                                                NaN       L1-25
# 617                                                NaN       L1-25
# 618                                                NaN       L1-25
# 619                                                NaN       L1-25
# 620                                                NaN       L1-25
#
# [621 rows x 19 columns]

# %%
df_pesquisa_alunos_lancamentos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 621 entries, 0 to 620
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   data_inscricao              621 non-null    datetime64[ns]
#  1   email                       621 non-null    object
#  2   data_nascimento             616 non-null    datetime64[ns]
#  3   profissao                   621 non-null    object
#  4   genero                      621 non-null    object
#  5   faixa_etaria                621 non-null    object
#  6   escolaridade                621 non-null    object
#  7   pais                        621 non-null    object
#  8   estado                      621 non-null    object
#  9   renda_media                 621 non-null    object
#  10  como_comprou_portal         621 non-null    object
#  11  tempo_antes_portal          621 non-null    object
#  12  onde_acompanha_conteudo     621 non-null    object
#  13  nivel_idioma                621 non-null    object
#  14  fala_outro_idioma           621 non-null    object
#  15  motivo_fluencia_espanhol    621 non-null    object
#  16  problema_aprender           621 non-null    object
#  17  interesse_renovacao_portal  587 non-null    object
#  18  lancamentos                 621 non-null    object
# dtypes: datetime64[ns](2), object(17)
# memory usage: 92.3+ KB

# %%
df_pesquisa_alunos_lancamentos['data_nascimento'] = df_pesquisa_alunos_lancamentos['data_nascimento'].fillna(pd.Timestamp('1900-01-01'))
df_pesquisa_alunos_lancamentos.rename(columns={'escolaridade': 'escolaridade_categoria'}, inplace=True)

# %%
df_pesquisa_alunos_lancamentos["interesse_renovacao_portal"] = (
    df_pesquisa_alunos_lancamentos["interesse_renovacao_portal"]
    .replace({
        "Sim, eu quero ter mais tranquilidade para estudar!": 1,
        "Não, obrigado": 0
    })
    .astype("Int64")  # permite int + NaN se necessário
)

df_pesquisa_alunos_lancamentos["tempo_antes_portal"] = (
    df_pesquisa_alunos_lancamentos["tempo_antes_portal"]
    .replace({
        "Conheci durante o evento gratuito": "Evento Gratuito",
        "Há mais de um mês e menos de 3 meses": "Entre 1 e 3 meses",
        "Mais de 3 meses e menos de 1 ano": "Entre 3 meses e 1 ano",
        "Conheci desde Dezembro de 2023.": "Desde Dez 2023"
    })
)

df_pesquisa_alunos_lancamentos["nivel_idioma"] = (
    df_pesquisa_alunos_lancamentos["nivel_idioma"]
    .replace({
        "Iniciante — dando os primeiros passos e vou melhorar muito": "Iniciante",
        "Intermediário — já entende muita coisa, mas tenho dificuldade pra falar": "Intermediário",
        "Perdido, mas estou motivado a mudar!": "Perdido",
        "Avançado — estou aqui para me aprofundar ainda mais": "Avançado",
        "Me vejo como iniciante, já tive aulas intensivas anteriormente, mas como parei faz um tempinho, me vejo como iniciante.": "Iniciante (voltando)"
    })
)

df_pesquisa_alunos_lancamentos["renda_media"] = (
    df_pesquisa_alunos_lancamentos["renda_media"]
    .replace({
        "Até R$1.500,00": "Até 1.500",
        "De R$1.500,01 à R$2.500,00": "De 1.500 a 2.500",
        "De R$2.500,01 a R$5.000,00": "De 2.500 a 5.000",
        "De R$5.000 a R$10.000": "De 5.000 a 10.000",
        "Mais de R$5.000,00": "De 5.000 a 10.000",
        "De R$2.500,01 à R$5.000,00": "De 2.500 a 5.000",
        "Mais de R$10.000": "Mais de 10.000"
    })
)

df_pesquisa_alunos_lancamentos["onde_acompanha_conteudo"] = (
    df_pesquisa_alunos_lancamentos["onde_acompanha_conteudo"]
    .replace({
        "Acompanho pelo Instagram, Youtube, TikTok.": "Outros"
    })
)

# %%
model = SentenceTransformer("all-MiniLM-L6-v2")

# Mapas distintos por coluna
mapeamentos = {
    'problema_aprender': mapeamento_problema_aprender,
    'profissao': mapeamento_profissoes,
    'fala_outro_idioma': mapeamento_outros_idiomas,
    'motivo_fluencia_espanhol': mapeamento_motivo_fluencia,
    'pais': mapeamento_paises,
    'estado': mapeamento_estados
}

for coluna, mapeamento in mapeamentos.items():
    nome_coluna_categoria = f"{coluna}_categoria"

    # Expandir mapeamento para esta coluna
    mapeamento_expandido, mapeamento_embeddings = preparar_para_categoria(mapeamento, model)

    # Categorização com o mapeamento certo
    df_pesquisa_alunos_lancamentos.loc[:, nome_coluna_categoria] = categorizar_coluna_batch(
        df_pesquisa_alunos_lancamentos[coluna],
        mapeamento_expandido,
        mapeamento_embeddings,
        model,
        threshold=0.6,
        desc=coluna
    )
# Out:
# problema_aprender (busca direta): 100%|███████████████████████████████████████████| 621/621 [00:00<00:00, 18817.91it/s]
# profissao (busca direta): 100%|███████████████████████████████████████████████████| 621/621 [00:00<00:00, 22346.30it/s]
# fala_outro_idioma (busca direta): 100%|███████████████████████████████████████████| 621/621 [00:00<00:00, 21906.33it/s]
# motivo_fluencia_espanhol (busca direta): 100%|████████████████████████████████████| 621/621 [00:00<00:00, 19609.88it/s]
# pais (busca direta): 100%|████████████████████████████████████████████████████████| 621/621 [00:00<00:00, 31372.03it/s]
# estado (busca direta): 100%|██████████████████████████████████████████████████████| 621/621 [00:00<00:00, 30692.20it/s]

# %%
# Exibir strings completas
pd.set_option("display.max_colwidth", None)

# Colunas categorizadas e respectivas colunas originais
categorias = {
    "profissao": "profissao_categoria",
    "pais": "pais_categoria",
    "estado": "estado_categoria",
    "fala_outro_idioma": "fala_outro_idioma_categoria",
    "motivo_fluencia_espanhol": "motivo_fluencia_espanhol_categoria",
    "problema_aprender": "problema_aprender_categoria"
}

# Categorias problemáticas que queremos revisar
categorias_problema = ["Outros", "Não Informou"]

# Loop para filtrar e mostrar os valores
for original_col, categoria_col in categorias.items():
    for problema in categorias_problema:
        print(f"\n=== Top 100 valores de '{original_col}' categorizados como '{problema}' ===")

        filtro = df_pesquisa_alunos_lancamentos[categoria_col] == problema
        valores = df_pesquisa_alunos_lancamentos.loc[filtro, original_col].value_counts().head(100)

        # Adiciona aspas
        valores.index = [f'"{val}"' for val in valores.index]

        print(valores)
# Out:
# === Top 100 valores de 'profissao' categorizados como 'Outros' ===
# "-"        1
# "24242"    1
# Name: count, dtype: int64
#
# === Top 100 valores de 'profissao' categorizados como 'Não Informou' ===
# "NDA"        1
# "Rep Com"    1
# Name: count, dtype: int64
#
# === Top 100 valores de 'pais' categorizados como 'Outros' ===
# "424242"    1
# Name: count, dtype: int64
#
# === Top 100 valores de 'pais' categorizados como 'Não Informou' ===
# Series([], Name: count, dtype: int64)
#
# === Top 100 valores de 'estado' categorizados como 'Outros' ===
# "Pardes Hanna Karkur"    2
# "São Paulo-Campinas"     1
# "Bernal"                 1
# "Buenos Aires"           1
# "Rio de Janeiro/RJ"      1
# "Minas Geraes "          1
# "Querétaro"              1
# "Carrasco del Sauce"     1
# "42424"                  1
# Name: count, dtype: int64
#
# === Top 100 valores de 'estado' categorizados como 'Não Informou' ===
# Series([], Name: count, dtype: int64)
#
# === Top 100 valores de 'fala_outro_idioma' categorizados como 'Outros' ===
# "Yanomai (Da Terra indígena yanomami)"    1
# "Libras"                                  1
# "Crioulo do Haiti "                       1
# "um pouco de francês"                     1
# "Coreano"                                 1
# "Tenho conhecimento básico"               1
# "estou aprendendo italiano"               1
# "Francês (muito pouco)"                   1
# Name: count, dtype: int64
#
# === Top 100 valores de 'fala_outro_idioma' categorizados como 'Não Informou' ===
# Series([], Name: count, dtype: int64)
#
# === Top 100 valores de 'motivo_fluencia_espanhol' categorizados como 'Outros' ===
# "Estou indo fazer Medicina "                                                                             1
# "Todos"                                                                                                  1
# "Respostas 1 e 2. Minha maior dificuldade é falar/responder/convesar em espanhol."                       1
# "Assumi um novo cargo que preciso atender clientes que falam espanhol"                                   1
# "Para ser comissária de voo"                                                                             1
# "fazer venda na america latina"                                                                          1
# "Acadêmico "                                                                                             1
# "Estou estudando medicina no Paraguai"                                                                   1
# "Por questões profissionais"                                                                             1
# "Que trabalhar de forma voluntária e poder ajudar os venezuelanos que estão mudando para nosso país "    1
# Name: count, dtype: int64
#
# === Top 100 valores de 'motivo_fluencia_espanhol' categorizados como 'Não Informou' ===
# Series([], Name: count, dtype: int64)
#
# === Top 100 valores de 'problema_aprender' categorizados como 'Outros' ===
# "O carisma da profe Juliana. É contagiante"                                                                    1
# "Indicação "                                                                                                   1
# "escolas tradicionais demoram muito para se chegar a nível avançado e tb tem muitas provas para se fazer. "    1
# "Respostas 1 e 3"                                                                                              1
# "Entrenar o que lo aprendi solo y evolucionar"                                                                 1
# "Gostei do jeito simples da língua que a pro Ju passou as informações - "                                      1
# "Que atendesse minhas necessidades "                                                                           1
# "Acesso gratuito por 1 semana para conhecer o VHE"                                                             1
# "Promoção semana gratuita "                                                                                    1
# Name: count, dtype: int64
#
# === Top 100 valores de 'problema_aprender' categorizados como 'Não Informou' ===
# Series([], Name: count, dtype: int64)

# %%
df_pesquisa_alunos_lancamentos["email"] = df_pesquisa_alunos_lancamentos["email"].str.lower()
df_pesquisa_alunos_lancamentos = df_pesquisa_alunos_lancamentos.drop_duplicates(subset='email', keep='first')

df_pesquisa_alunos_lancamentos.shape
# Out:
# (585, 25)

# %%
df_pesquisa_alunos_lancamentos = df_pesquisa_alunos_lancamentos.drop([
    'profissao',
    'pais',
    'estado',
    'fala_outro_idioma',
    'motivo_fluencia_espanhol',
    'problema_aprender'
], axis=1, errors='ignore')

# %%
# Definir colunas categóricas não ordenadas
colunas_categoricas_nao_ordenadas = [
    "email",
    "genero",
    "como_comprou_portal",
    "onde_acompanha_conteudo",
    "profissao_categoria",
    "pais_categoria",
    "estado_categoria",
    "fala_outro_idioma_categoria",
    "motivo_fluencia_espanhol_categoria",
    "problema_aprender_categoria"
]

# Definir colunas categóricas ordenadas 
colunas_categoricas_ordenadas = [
    "faixa_etaria",
    "escolaridade_categoria",
    "renda_media",
    "tempo_antes_portal",
    "nivel_idioma",
    "lancamentos"
]

# Definir colunas de datas ordenadas
colunas_datas = [
    "data_inscricao",
    "data_nascimento"
]

# Definir colunas numéricas automaticamente (excluindo as categóricas e a variável-alvo)
colunas_numericas = [
    coluna for coluna in df_pesquisa_alunos_lancamentos.columns if coluna not in (
        colunas_categoricas_nao_ordenadas + colunas_categoricas_ordenadas + colunas_datas
    )
]

# %%
# Cópia explícita do DataFrame para evitar o SettingWithCopyWarning
df_pesquisa_alunos_lancamentos = df_pesquisa_alunos_lancamentos.copy()

# Definir as ordens como listas
faixa_etaria_order = ['14 - 17', '18 - 24', '25 - 34', '35 - 44', '44 - 55', '+55']
escolaridade_categoria_order = ['Fundamental completo', 'Médio incompleto', 'Médio completo', 'Superior incompleto', 'Superior completo', 'Pós-graduação completa']
renda_media_order = ['Não tenho renda.', 'Até 1.500', 'De 1.500 a 2.500', 'De 2.500 a 5.000', 'De 5.000 a 10.000', 'Mais de 10.000']
tempo_antes_portal_order = ['Evento Gratuito', 'Entre 1 e 3 meses', 'Entre 3 meses e 1 ano', 'Mais de 1 ano', 'Desde Dez 2023']
nivel_idioma_order = ['Perdido', 'Iniciante', 'Iniciante (voltando)', 'Intermediário', 'Avançado']
lancamentos_order = ['L3-24', 'L4-24', 'L1-25']

# Aplicar a nova ordem das categorias diretamente com .astype("category") seguido de .cat.set_categories
df_pesquisa_alunos_lancamentos['faixa_etaria'] = df_pesquisa_alunos_lancamentos['faixa_etaria'].astype("category").cat.set_categories(faixa_etaria_order, ordered=True)
df_pesquisa_alunos_lancamentos['escolaridade_categoria'] = df_pesquisa_alunos_lancamentos['escolaridade_categoria'].astype("category").cat.set_categories(escolaridade_categoria_order, ordered=True)
df_pesquisa_alunos_lancamentos['renda_media'] = df_pesquisa_alunos_lancamentos['renda_media'].astype("category").cat.set_categories(renda_media_order, ordered=True)
df_pesquisa_alunos_lancamentos['tempo_antes_portal'] = df_pesquisa_alunos_lancamentos['tempo_antes_portal'].astype("category").cat.set_categories(tempo_antes_portal_order, ordered=True)
df_pesquisa_alunos_lancamentos['nivel_idioma'] = df_pesquisa_alunos_lancamentos['nivel_idioma'].astype("category").cat.set_categories(nivel_idioma_order, ordered=True)
df_pesquisa_alunos_lancamentos['lancamentos'] = df_pesquisa_alunos_lancamentos['lancamentos'].astype("category").cat.set_categories(lancamentos_order, ordered=True)

# %%
df_pesquisa_alunos_lancamentos = df_pesquisa_alunos_lancamentos.copy()

# Conversão garantida para não ordenadas
for col in colunas_categoricas_nao_ordenadas:
    df_pesquisa_alunos_lancamentos[col] = df_pesquisa_alunos_lancamentos[col].astype("category")

# %%
for coluna in (colunas_categoricas_nao_ordenadas + colunas_categoricas_ordenadas):
    print(f"{coluna}: {df_pesquisa_alunos_lancamentos[coluna].unique()}")
    print()
# Out:
# email: ['teofilotavares@icloud.com', 'leosantanati@outlook.com', 'flaviojatoba@outlook.com', 'alandematos10@hotmail.com', 'vanessavirginia2019@gmail.com', ..., 'joaofurtadon@gmail.com', 'moreirapriscilla@yahoo.com.br', 'bilam@uol.com.br', 'jurodrigues96@gmail.com', 'juninhocosta000@gmail.com']
# Length: 585
# Categories (585, object): ['18esms@gmail.com', 'a.demite@gmail.com', 'a1seculo@gmail.com', 'acsa.winchestter157@gmail.com', ..., 'yaraschulz1@outlook.com', 'yvencarvalho23@icloud.com', 'yvisglopes@gmail.com', 'zealvaro@dieese.org.br']
#
# genero: ['Masculino', 'Feminino']
# Categories (2, object): ['Feminino', 'Masculino']
#
# como_comprou_portal: ['Comprei com o meu próprio dinheiro', 'Ganhei de presente', 'Meus pais (ou parentes) me ajudaram', 'Pedi emprestado', 'Conheci através do Youtube']
# Categories (5, object): ['Comprei com o meu próprio dinheiro', 'Conheci através do Youtube', 'Ganhei de presente', 'Meus pais (ou parentes) me ajudaram', 'Pedi emprestado']
#
# onde_acompanha_conteudo: ['YouTube', 'Não acompanhava', 'Instagram', 'Outros']
# Categories (4, object): ['Instagram', 'Não acompanhava', 'Outros', 'YouTube']
#
# profissao_categoria: ['Saúde', 'Empreendedorismo', 'Publicidade', 'Vendas', 'Criativo-Arte', ..., 'Recursos Humanos', 'Infraestrutura Logística', 'Desempregado', 'Arqueologia-Ciência', 'Outros']
# Length: 31
# Categories (31, object): ['Administrativo', 'Aeronáutica', 'Alimentação Nutrição', 'Aposentado', ..., 'Tecnologia', 'Turismo', 'Técnico Operacional', 'Vendas']
#
# pais_categoria: ['Brasil', 'Espanha', 'Estados Unidos', 'Argentina', 'Portugal', ..., 'Equador', 'Uruguai', 'Israel', 'Itália', 'Outros']
# Length: 14
# Categories (14, object): ['Argentina', 'Brasil', 'Equador', 'Espanha', ..., 'Paraguai', 'Polônia', 'Portugal', 'Uruguai']
#
# estado_categoria: ['GO', 'SP', 'MG', 'Estrangeiro', 'AC', ..., 'RN', 'AP', 'CE', 'PB', 'RO']
# Length: 29
# Categories (29, object): ['AC', 'AL', 'AM', 'AP', ..., 'SC', 'SE', 'SP', 'TO']
#
# fala_outro_idioma_categoria: ['Não Fala Outro Idioma', 'Inglês Intermediário ou Avançado', 'Inglês Básico', 'Outros', 'Espanhol', 'Inglês + Outros Idiomas']
# Categories (6, object): ['Espanhol', 'Inglês + Outros Idiomas', 'Inglês Básico', 'Inglês Intermediário ou Avançado', 'Não Fala Outro Idioma', 'Outros']
#
# motivo_fluencia_espanhol_categoria: ['Quero viajar e viver experiências marcantes me comunicando com confiança', 'Morar no exterior', 'Outros', 'Intercâmbio', 'Gosto do idioma e quero aprender por hobby', ..., 'Família', 'Prova de Proficiência', 'Docência', 'Todas Alternativas Acima', 'Voluntariado']
# Length: 13
# Categories (13, object): ['Aprendizado e Aperfeiçoamento', 'Conquistar um emprego melhor e ganhar mais', 'Descendência Hispana', 'Docência', ..., 'Prova de Proficiência', 'Quero viajar e viver experiências marcantes me comunicando com confiança', 'Todas Alternativas Acima', 'Voluntariado']
#
# problema_aprender_categoria: ['Falta de tempo', 'Falta de disciplina / foco', 'Não sei por onde começar', 'Falta de método', 'Dificuldade com pronúncia', ..., 'Problemas financeiros', 'Dificuldade com a gramática', 'Falta de conhecimento prévio', 'Nada impede', 'Falta de prática / escuta']
# Length: 13
# Categories (13, object): ['Dificuldade com a gramática', 'Dificuldade com pronúncia', 'Falta de conhecimento prévio', 'Falta de curso presencial / professor ao vivo', ..., 'Nada impede', 'Não sei por onde começar', 'Outros', 'Problemas financeiros']
#
# faixa_etaria: ['35 - 44', '25 - 34', '44 - 55', '18 - 24', '+55', '14 - 17']
# Categories (6, object): ['14 - 17' < '18 - 24' < '25 - 34' < '35 - 44' < '44 - 55' < '+55']
#
# escolaridade_categoria: ['Pós-graduação completa', 'Médio completo', 'Superior completo', 'Superior incompleto', 'Médio incompleto', 'Fundamental completo']
# Categories (6, object): ['Fundamental completo' < 'Médio incompleto' < 'Médio completo' < 'Superior incompleto' < 'Superior completo' < 'Pós-graduação completa']
#
# renda_media: ['Mais de 10.000', 'De 2.500 a 5.000', 'De 1.500 a 2.500', 'Não tenho renda.', 'De 5.000 a 10.000', 'Até 1.500']
# Categories (6, object): ['Não tenho renda.' < 'Até 1.500' < 'De 1.500 a 2.500' < 'De 2.500 a 5.000' < 'De 5.000 a 10.000' < 'Mais de 10.000']
#
# tempo_antes_portal: ['Entre 1 e 3 meses', 'Evento Gratuito', 'Mais de 1 ano', 'Entre 3 meses e 1 ano', 'Desde Dez 2023']
# Categories (5, object): ['Evento Gratuito' < 'Entre 1 e 3 meses' < 'Entre 3 meses e 1 ano' < 'Mais de 1 ano' < 'Desde Dez 2023']
#
# nivel_idioma: ['Iniciante', 'Intermediário', 'Perdido', 'Avançado', 'Iniciante (voltando)']
# Categories (5, object): ['Perdido' < 'Iniciante' < 'Iniciante (voltando)' < 'Intermediário' < 'Avançado']
#
# lancamentos: ['L3-24', 'L4-24', 'L1-25']
# Categories (3, object): ['L3-24' < 'L4-24' < 'L1-25']

# %%
# Caminho de destino
caminho_csv = r"C:\Users\Camilo_Bica\data_science\consultoria\portal_vhe\dados\pesquisa_alunos_lancamentos.csv"

# Exportar para CSV com separador padrão (vírgula) e sem índice
df_pesquisa_alunos_lancamentos.to_csv(caminho_csv, index=False, encoding='utf-8-sig')

# %%
df_pesquisa_alunos_lancamentos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 585 entries, 0 to 620
# Data columns (total 19 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   data_inscricao                      585 non-null    datetime64[ns]
#  1   email                               585 non-null    category
#  2   data_nascimento                     585 non-null    datetime64[ns]
#  3   genero                              585 non-null    category
#  4   faixa_etaria                        585 non-null    category
#  5   escolaridade_categoria              585 non-null    category
#  6   renda_media                         585 non-null    category
#  7   como_comprou_portal                 585 non-null    category
#  8   tempo_antes_portal                  585 non-null    category
#  9   onde_acompanha_conteudo             585 non-null    category
#  10  nivel_idioma                        585 non-null    category
#  11  interesse_renovacao_portal          552 non-null    Int64
#  12  lancamentos                         585 non-null    category
#  13  problema_aprender_categoria         585 non-null    category
#  14  profissao_categoria                 585 non-null    category
#  15  fala_outro_idioma_categoria         585 non-null    category
#  16  motivo_fluencia_espanhol_categoria  585 non-null    category
#  17  pais_categoria                      585 non-null    category
#  18  estado_categoria                    585 non-null    category
# dtypes: Int64(1), category(16), datetime64[ns](2)
# memory usage: 55.7 KB

# %%
df_pesquisa_alunos_lancamentos.head()
# Out:
#   data_inscricao                          email data_nascimento     genero  \
# 0     2024-05-14      teofilotavares@icloud.com      1983-01-06  Masculino
# 1     2024-05-16       leosantanati@outlook.com      1995-07-16  Masculino
# 2     2024-05-16       flaviojatoba@outlook.com      1992-10-28  Masculino
# 3     2024-05-17      alandematos10@hotmail.com      1982-05-08  Masculino
# 5     2024-05-17  vanessavirginia2019@gmail.com      1985-06-08   Feminino
#
#   faixa_etaria  escolaridade_categoria       renda_media  \
# 0      35 - 44  Pós-graduação completa    Mais de 10.000
# 1      25 - 34          Médio completo  De 2.500 a 5.000
# 2      25 - 34       Superior completo  De 2.500 a 5.000
# 3      35 - 44       Superior completo  De 1.500 a 2.500
# 5      35 - 44       Superior completo  Não tenho renda.
#
#                   como_comprou_portal tempo_antes_portal  \
# 0  Comprei com o meu próprio dinheiro  Entre 1 e 3 meses
# 1  Comprei com o meu próprio dinheiro    Evento Gratuito
# 2  Comprei com o meu próprio dinheiro    Evento Gratuito
# 3  Comprei com o meu próprio dinheiro    Evento Gratuito
# 5                  Ganhei de presente  Entre 1 e 3 meses
#
#   onde_acompanha_conteudo nivel_idioma  interesse_renovacao_portal  \
# 0                 YouTube    Iniciante                           0
# 1                 YouTube    Iniciante                           0
# 2         Não acompanhava    Iniciante                           0
# 3                 YouTube    Iniciante                           1
# 5                 YouTube    Iniciante                           1
#
#   lancamentos problema_aprender_categoria profissao_categoria  \
# 0       L3-24              Falta de tempo               Saúde
# 1       L3-24  Falta de disciplina / foco    Empreendedorismo
# 2       L3-24  Falta de disciplina / foco         Publicidade
# 3       L3-24    Não sei por onde começar               Saúde
# 5       L3-24    Não sei por onde começar              Vendas
#
#   fala_outro_idioma_categoria  \
# 0       Não Fala Outro Idioma
# 1       Não Fala Outro Idioma
# 2       Não Fala Outro Idioma
# 3       Não Fala Outro Idioma
# 5       Não Fala Outro Idioma
#
#                                          motivo_fluencia_espanhol_categoria  \
# 0  Quero viajar e viver experiências marcantes me comunicando com confiança
# 1                                                         Morar no exterior
# 2                                                         Morar no exterior
# 3                                                                    Outros
# 5                                                         Morar no exterior
#
#   pais_categoria estado_categoria
# 0         Brasil               GO
# 1         Brasil               SP
# 2         Brasil               SP
# 3         Brasil               MG
# 5        Espanha      Estrangeiro

# %%
colunas_excluir = [
    "data_inscricao", 
    "email", 
    "data_nascimento"
]

for coluna in df_pesquisa_alunos_lancamentos.columns:
    if coluna not in colunas_excluir:
        print(f"\nColuna: {coluna}")
        print(df_pesquisa_alunos_lancamentos[coluna].value_counts(dropna=False))
# Out:
# Coluna: genero
# genero
# Feminino     417
# Masculino    168
# Name: count, dtype: int64
#
# Coluna: faixa_etaria
# faixa_etaria
# 25 - 34    184
# 35 - 44    166
# 44 - 55    125
# +55         68
# 18 - 24     41
# 14 - 17      1
# Name: count, dtype: int64
#
# Coluna: escolaridade_categoria
# escolaridade_categoria
# Pós-graduação completa    239
# Superior completo         173
# Médio completo             85
# Superior incompleto        73
# Médio incompleto           12
# Fundamental completo        3
# Name: count, dtype: int64
#
# Coluna: renda_media
# renda_media
# De 2.500 a 5.000     162
# De 5.000 a 10.000    139
# De 1.500 a 2.500     101
# Mais de 10.000        88
# Até 1.500             52
# Não tenho renda.      43
# Name: count, dtype: int64
#
# Coluna: como_comprou_portal
# como_comprou_portal
# Comprei com o meu próprio dinheiro     487
# Ganhei de presente                      55
# Meus pais (ou parentes) me ajudaram     32
# Pedi emprestado                         10
# Conheci através do Youtube               1
# Name: count, dtype: int64
#
# Coluna: tempo_antes_portal
# tempo_antes_portal
# Evento Gratuito          216
# Entre 1 e 3 meses        171
# Entre 3 meses e 1 ano    127
# Mais de 1 ano             70
# Desde Dez 2023             1
# Name: count, dtype: int64
#
# Coluna: onde_acompanha_conteudo
# onde_acompanha_conteudo
# YouTube            250
# Instagram          230
# Não acompanhava    104
# Outros               1
# Name: count, dtype: int64
#
# Coluna: nivel_idioma
# nivel_idioma
# Iniciante               329
# Intermediário           151
# Perdido                 102
# Avançado                  2
# Iniciante (voltando)      1
# Name: count, dtype: int64
#
# Coluna: interesse_renovacao_portal
# interesse_renovacao_portal
# 0       432
# 1       120
# <NA>     33
# Name: count, dtype: Int64
#
# Coluna: lancamentos
# lancamentos
# L3-24    277
# L4-24    275
# L1-25     33
# Name: count, dtype: int64
#
# Coluna: problema_aprender_categoria
# problema_aprender_categoria
# Não sei por onde começar                         153
# Falta de método                                  142
# Falta de tempo                                   100
# Falta de disciplina / foco                        97
# Dificuldade com pronúncia                         64
# Outros                                             9
# Falta de oportunidade                              6
# Falta de curso presencial / professor ao vivo      4
# Falta de conhecimento prévio                       3
# Nada impede                                        3
# Dificuldade com a gramática                        2
# Falta de prática / escuta                          1
# Problemas financeiros                              1
# Name: count, dtype: int64
#
# Coluna: profissao_categoria
# profissao_categoria
# Administrativo              116
# Saúde                        67
# Docência                     59
# Técnico Operacional          37
# Vendas                       32
# Estudante                    31
# Empreendedorismo             31
# Criativo-Arte                26
# Jurídico                     23
# Contabilidade Finanças       20
# Segurança                    18
# Aposentado                   15
# Tecnologia                   13
# Arquitetura-Engenharia       10
# Doméstico                     9
# Beleza                        9
# Consultoria                   8
# Publicidade                   8
# Turismo                       7
# Aeronáutica                   6
# Desempregado                  6
# Recursos Humanos              5
# Corretora                     5
# Arqueologia-Ciência           4
# Religioso                     4
# Infraestrutura Logística      4
# Alimentação Nutrição          4
# Não Informou                  2
# Outros                        2
# Produção de Eventos           2
# Marketing                     2
# Name: count, dtype: int64
#
# Coluna: fala_outro_idioma_categoria
# fala_outro_idioma_categoria
# Não Fala Outro Idioma               397
# Inglês Intermediário ou Avançado    158
# Inglês Básico                        13
# Outros                                8
# Inglês + Outros Idiomas               7
# Espanhol                              2
# Name: count, dtype: int64
#
# Coluna: motivo_fluencia_espanhol_categoria
# motivo_fluencia_espanhol_categoria
# Quero viajar e viver experiências marcantes me comunicando com confiança    230
# Conquistar um emprego melhor e ganhar mais                                  143
# Morar no exterior                                                            67
# Gosto do idioma e quero aprender por hobby                                   55
# Intercâmbio                                                                  31
# Aprendizado e Aperfeiçoamento                                                14
# Descendência Hispana                                                         13
# Família                                                                      11
# Outros                                                                       10
# Docência                                                                      3
# Todas Alternativas Acima                                                      3
# Voluntariado                                                                  3
# Prova de Proficiência                                                         2
# Name: count, dtype: int64
#
# Coluna: pais_categoria
# pais_categoria
# Brasil            546
# Espanha             8
# Argentina           6
# Portugal            6
# Estados Unidos      5
# Paraguai            4
# Equador             2
# México              2
# Israel              1
# Itália              1
# Japão               1
# Outros              1
# Polônia             1
# Uruguai             1
# Name: count, dtype: int64
#
# Coluna: estado_categoria
# estado_categoria
# SP               209
# RJ                63
# MG                48
# PR                36
# Estrangeiro       25
# DF                25
# BA                21
# RS                19
# SC                15
# PE                13
# CE                11
# ES                 9
# Outros             9
# GO                 9
# MS                 8
# AM                 8
# PA                 8
# MA                 7
# RN                 6
# MT                 6
# PB                 5
# Não Informado      5
# AL                 4
# AC                 3
# RO                 3
# PI                 3
# TO                 3
# SE                 2
# AP                 2
# Name: count, dtype: int64
