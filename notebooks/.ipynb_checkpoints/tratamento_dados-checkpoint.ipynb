# %%
import gspread
import pandas as pd
import os
import numpy as np

from dotenv import load_dotenv
from google.oauth2 import service_account

# === Carregar variáveis de ambiente ===
load_dotenv()

# === Definir escopos de acesso ===
scopes = [
    "https://www.googleapis.com/auth/spreadsheets.readonly",
    "https://www.googleapis.com/auth/drive.readonly"
]

# === Caminho seguro para o arquivo JSON (lido do .env) ===
cred_path = os.getenv('GOOGLE_CREDENTIALS_PATH')

# === Carregar credenciais de forma moderna ===
creds = service_account.Credentials.from_service_account_file(
    cred_path,
    scopes=scopes
)

# === Autorizar o cliente gspread ===
client = gspread.authorize(creds)

# === Função para carregar aba da planilha ===
def carregar_aba(sheet_id, aba_nome):
    planilha = client.open_by_key(sheet_id)
    aba = planilha.worksheet(aba_nome)
    dados = aba.get_all_records()
    return pd.DataFrame(dados)

# === IDs das planilhas (fixar no .env depois se quiser) ===
id_dados_leads_ssp = "1K7nLxfgu6ktdyFwlHMPJsj5xdv410tensfPccmmPDm8"
id_pesquisa_ssp = "1pK0BP8n98DtQ8OwGeBhzcGgxQinFqZhZsQTk7_cYZIk"
id_compradores_ssp = "1A3D8JNPlZNpxkwcXQ_7CxalNEZyLo8KmJP6Sa_A-3NU"

# === Carregar DataFrames ===
df_leads_trafego = carregar_aba(id_dados_leads_ssp, "Página1")
df_leads_invest_trafego = carregar_aba(id_dados_leads_ssp, "Dados Investimento")
df_pesquisa_captacao = carregar_aba(id_pesquisa_ssp, "Página1")
df_compradores = carregar_aba(id_compradores_ssp, "Compradores")

# %%
df_pesquisa_captacao = df_pesquisa_captacao.drop(["Funil"], axis=1, errors='ignore')
df_pesquisa_captacao.rename(columns={'E-mail': 'email'}, inplace=True)
df_pesquisa_captacao.columns = df_pesquisa_captacao.columns.str.lower()

df_pesquisa_captacao['data'] = pd.to_datetime(df_pesquisa_captacao['data'], errors='coerce')
df_pesquisa_captacao['data'] = df_pesquisa_captacao['data'].dt.tz_localize(None)
df_pesquisa_captacao['data'] = df_pesquisa_captacao['data'].dt.normalize()

df_pesquisa_captacao["email"] = df_pesquisa_captacao["email"].str.lower().str.strip()
df_pesquisa_captacao = df_pesquisa_captacao.drop_duplicates(subset='email', keep='first')

df_pesquisa_captacao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27511 entries, 0 to 28297
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   data                   27511 non-null  datetime64[ns]
#  1   email                  27511 non-null  object
#  2   idade                  27511 non-null  object
#  3   nível                  27511 non-null  object
#  4   situação profissional  27511 non-null  object
#  5   renda                  27511 non-null  object
#  6   escolaridade           27511 non-null  object
#  7   duvida                 27511 non-null  object
#  8   dificuldade            27511 non-null  object
# dtypes: datetime64[ns](1), object(8)
# memory usage: 2.1+ MB

# %%
df_pesquisa_captacao["renda"] = (
    df_pesquisa_captacao["renda"]
    .replace({
        "O a R$1.000\u2028": "De 0 a 1.000",
        "R$1.000 a R$3.000": "De 1.000 a 3.000",
        "R$3.000 a R$5.000\u2028": "De 3.000 a 5.000",
        "R$5.000 a R$10.000\u2028": "De 5.000 a 10.000",
        "Mais de R$10.000": "Mais de 10.000"
    })
)

df_pesquisa_captacao["escolaridade"] = (
    df_pesquisa_captacao["escolaridade"]
    .replace({
        "Ensino superior incompleto\u2028": "Ensino superior incompleto"
    })
)

# %%
# Filtrar o DataFrame para excluir linhas onde o email contém "teste" ou "x@x"
df_pesquisa_captacao = df_pesquisa_captacao[
    ~df_pesquisa_captacao['email'].str.contains('teste|x@x', case=False, na=False)
]

df_pesquisa_captacao
# Out:
#             data                           email  idade     nível  \
# 2     2025-04-07        manoeltarsis22@gmail.com  33-37   Técnica
# 3     2025-04-07  geovanarodrigues0106@gmail.com  23-27   Técnica
# 4     2025-04-07              jj272824@gmail.com  18-22  Superior
# 5     2025-04-07       iuriguerreiro45@gmail.com  28-32   Técnica
# 6     2025-04-07    stevaogabrieli2020@gmail.com  18-22   Técnica
# ...          ...                             ...    ...       ...
# 28293 2025-05-01     jonathanfelippe85@gmail.com  18-22   Técnica
# 28294 2025-05-01   marcelo_frameschi@hotmail.com  46-52  Superior
# 28295 2025-05-01        fs081973304059@gmail.com  23-27  Superior
# 28296 2025-05-01    wesleyantonichen91@gmail.com  28-32   Técnica
# 28297 2025-05-01             guhki9535@gmail.com  23-27   Técnica
#
#                 situação profissional                  renda  \
# 2                            Autônomo       De 1.000 a 3.000
# 3                     Desempregado(a)  Estou desempregado(a)
# 4                     Desempregado(a)  Estou desempregado(a)
# 5                     Desempregado(a)  Estou desempregado(a)
# 6                            Autônomo  Estou desempregado(a)
# ...                               ...                    ...
# 28293                 Desempregado(a)  Estou desempregado(a)
# 28294                        Autônomo       De 3.000 a 5.000
# 28295                        Autônomo           De 0 a 1.000
# 28296                 Desempregado(a)       De 1.000 a 3.000
# 28297  Funcionário de empresa privada       De 1.000 a 3.000
#
#                      escolaridade  \
# 2           Ensino médio completo
# 3      Ensino superior incompleto
# 4           Ensino médio completo
# 5          Nível técnico completo
# 6           Ensino médio completo
# ...                           ...
# 28293       Ensino médio completo
# 28294    Ensino superior completo
# 28295       Ensino médio completo
# 28296       Ensino médio completo
# 28297       Ensino médio completo
#
#                                                   duvida          dificuldade
# 2                         O que preciso pra ser aprovado                Tempo
# 3                                                      .     Separa material
# 4                      O quão difícil é conseguir passar             Nenhuma
# 5         Em qual lugar do Brasil pode fazer o concurso?                Tempo
# 6                         Se precisa de ensino superior               Nenhuma
# ...                                                  ...                  ...
# 28293                              Será q tenho chance ?             Nenhuma
# 28294                   Período e condições de trabalho              Horário
# 28295          Garanti minha vaga e crece com a empresa              Nenhuma
# 28296  Como entrar em contato e ter uma oportunidade ...      Seria horários
# 28297                                                  1  Não há dificuldade
#
# [27504 rows x 9 columns]

# %%
df_leads_trafego.rename(columns={'E-mail': 'email'}, inplace=True)
df_leads_trafego.columns = df_leads_trafego.columns.str.lower()

df_leads_trafego['data'] = pd.to_datetime(df_leads_trafego['data'], errors='coerce')
df_leads_trafego['data'] = df_leads_trafego['data'].dt.tz_localize(None)
df_leads_trafego['data'] = df_leads_trafego['data'].dt.normalize()

df_leads_trafego["email"] = df_leads_trafego["email"].str.lower().str.strip()
df_leads_trafego = df_leads_trafego.drop_duplicates(subset='email', keep='first')
df_leads_trafego.columns = df_leads_trafego.columns.str.strip().str.lower().str.replace(" ", "_")

df_leads_trafego.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44784 entries, 0 to 44875
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   data          44784 non-null  datetime64[ns]
#  1   nome          44784 non-null  object
#  2   email         44784 non-null  object
#  3   utm_source    44784 non-null  object
#  4   utm_campaign  44784 non-null  object
#  5   utm_medium    44784 non-null  object
#  6   utm_content   44784 non-null  object
#  7   tag           44784 non-null  object
# dtypes: datetime64[ns](1), object(7)
# memory usage: 3.1+ MB
# C:\Users\Camilo_Bica\AppData\Local\Temp\ipykernel_12228\216663922.py:4: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_leads_trafego['data'] = pd.to_datetime(df_leads_trafego['data'], errors='coerce')

# %%
# Definir colunas UTM
colunas_utms = ['utm_source', 'utm_campaign', 'utm_medium', 'utm_content']

# Função para verificar se uma célula é "vazia de verdade"
def is_vazio(valor):
    if pd.isna(valor):
        return True
    valor = str(valor).strip()
    return (valor == "") or (valor.startswith("{{") and valor.endswith("}}"))

# Função para verificar se TODAS UTMs estão vazias para uma linha
def todas_utms_vazias(row):
    return all(is_vazio(row[col]) for col in colunas_utms)

# Aplicar filtro: manter linhas onde pelo menos uma UTM está preenchida de verdade
df_leads_trafego = df_leads_trafego[
    ~df_leads_trafego.apply(todas_utms_vazias, axis=1)
].copy()

# Resetar índice
df_leads_trafego = df_leads_trafego.reset_index(drop=True)

df_leads_trafego
# Out:
#             data       nome                          email    utm_source  \
# 0     2025-03-31     Rafael     rafael@agenciascale.com.br         teste
# 1     2025-03-31     Hermes             hermesc1@gmail.com  Facebook-Ads
# 2     2025-03-31      Geisa   santos.geisa.lucas@gmail.com  Facebook-Ads
# 3     2025-03-31  Uelington      uelingtonreis25@gmail.com  Facebook-Ads
# 4     2025-03-31     Vivian  vivian.serafim.xoxo@gmail.com  Facebook-Ads
# ...          ...        ...                            ...           ...
# 43350 2025-05-01    Rogerio           roggcar881@gmail.com  Facebook-Ads
# 43351 2025-05-01    Gustavo              guuhk22@gmail.com  Facebook-Ads
# 43352 2025-05-01     Wesley   wesleyantonichen91@gmail.com  Facebook-Ads
# 43353 2025-05-01    Jordiel     jordielfreitas08@gmail.com  Facebook-Ads
# 43354 2025-05-01    Antonio           acffortini@gmail.com  Facebook-Ads
#
#                                             utm_campaign  \
# 0                                                  teste
# 1      SSP-L12 | CAPTACAO | CBO | FRIO | ALL | BR | 3...
# 2      SSP-L12 | CAPTACAO | CBO | FRIO | ALL | BR | 3...
# 3      SSP-L12 | CAPTACAO | CBO | FRIO | ALL | BR | 3...
# 4      SSP-L12 | CAPTACAO | CBO | FRIO | ALL | BR | 3...
# ...                                                  ...
# 43350  SSP-L13 | CAPTACAO | CBO | FRIO | ALL | BR | 3...
# 43351  SSP-L13 | CAPTACAO | CBO | FRIO | ALL | BR | 3...
# 43352  SSP-L13 | CAPTACAO | CBO | FRIO | ALL | BR | 3...
# 43353  SSP-L13 | CAPTACAO | CBO | FRIO | ALL | BR | 3...
# 43354  SSP-L13 | CAPTACAO | CBO | FRIO | ALL | BR | 3...
#
#                                           utm_medium  \
# 0                                              teste
# 1          00 | AUTO | LAL | 1% | ENVOLVIMENTO IG 7D
# 2          00 | AUTO | LAL | 1% | ENVOLVIMENTO IG 7D
# 3        00 | AUTO | LAL | 1%  | ENVOLVIMENTO IG 14D
# 4        00 | AUTO | LAL | 1%  | ENVOLVIMENTO IG 14D
# ...                                              ...
# 43350    00 | AUTO | LAL | 1%  | ENVOLVIMENTO IG 14D
# 43351    00 | AUTO | LAL | 1%  | ENVOLVIMENTO IG 14D
# 43352  00 | AUTO | LAL | 1%  | ENVOLVIMENTO IG | 30D
# 43353    00 | AUTO | LAL | 1%  | ENVOLVIMENTO IG 14D
# 43354      00 | AUTO | LAL | 1% | ENVOLVIMENTO IG 7D
#
#                         utm_content      tag
# 0                             teste  SSP-L12
# 1          ADS_002_ANUNCIO PETRO 02  SSP-L12
# 2          ADS_002_ANUNCIO PETRO 02  SSP-L12
# 3          ADS_003_ANUNCIO PETRO 03  SSP-L12
# 4          ADS_003_ANUNCIO PETRO 03  SSP-L12
# ...                             ...      ...
# 43350  ADS_VID_002_ANUNCIO PETRO 02
# 43351  ADS_VID_002_ANUNCIO PETRO 02
# 43352  ADS_VID_002_ANUNCIO PETRO 02
# 43353  ADS_VID_002_ANUNCIO PETRO 02
# 43354  ADS_VID_002_ANUNCIO PETRO 02
#
# [43355 rows x 8 columns]

# %%
df_leads_trafego.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43355 entries, 0 to 43354
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   data          43355 non-null  datetime64[ns]
#  1   nome          43355 non-null  object
#  2   email         43355 non-null  object
#  3   utm_source    43355 non-null  object
#  4   utm_campaign  43355 non-null  object
#  5   utm_medium    43355 non-null  object
#  6   utm_content   43355 non-null  object
#  7   tag           43355 non-null  object
# dtypes: datetime64[ns](1), object(7)
# memory usage: 2.6+ MB

# %%
df_leads_invest_trafego['date'] = pd.to_datetime(df_leads_invest_trafego['date'], errors='coerce')
df_leads_invest_trafego['date'] = df_leads_invest_trafego['date'].dt.tz_localize(None)
df_leads_invest_trafego['date'] = df_leads_invest_trafego['date'].dt.normalize()

df_leads_invest_trafego.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 788 entries, 0 to 787
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   date                       788 non-null    datetime64[ns]
#  1   campaign                   788 non-null    object
#  2   adset_name                 788 non-null    object
#  3   ad_name                    788 non-null    object
#  4   spend                      788 non-null    int64
#  5   impressions                788 non-null    int64
#  6   actions_link_click         788 non-null    int64
#  7   actions_landing_page_view  788 non-null    int64
# dtypes: datetime64[ns](1), int64(4), object(3)
# memory usage: 49.4+ KB
# C:\Users\Camilo_Bica\AppData\Local\Temp\ipykernel_12228\352342578.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_leads_invest_trafego['date'] = pd.to_datetime(df_leads_invest_trafego['date'], errors='coerce')

# %%
# Lista das colunas que queremos validar
colunas_investimento = ['spend', 'impressions', 'actions_link_click', 'actions_landing_page_view']

# Garantir que essas colunas sejam numéricas (importante!)
for col in colunas_investimento:
    df_leads_invest_trafego[col] = (
        df_leads_invest_trafego[col]
        .astype(str)
        .str.replace(',', '.', regex=False)
        .astype(float)
    )

# Agora, remover linhas onde TODAS essas colunas são zero
df_leads_invest_trafego = df_leads_invest_trafego[
    ~(df_leads_invest_trafego[colunas_investimento] == 0).all(axis=1)
].copy()

# Ajustar df_leads_invest_trafego para nomes iguais
df_leads_invest_trafego = df_leads_invest_trafego.rename(columns={
    'date': 'data',
    'campaign': 'utm campaign',
    'adset_name': 'utm medium',
    'ad_name': 'utm content'
})

# Resetar índice (opcional, para organização)
df_leads_invest_trafego = df_leads_invest_trafego.reset_index(drop=True)

# %%
df_leads_invest_trafego
# Out:
#           data                                       utm campaign  \
# 0   2025-03-31  SSP-L12 | CAPTACAO | CBO | FRIO | ALL | BR | 3...
# 1   2025-03-31  SSP-L12 | CAPTACAO | CBO | FRIO | ALL | BR | 3...
# 2   2025-03-31  SSP-L12 | CAPTACAO | CBO | FRIO | ALL | BR | 3...
# 3   2025-03-31  SSP-L12 | CAPTACAO | CBO | FRIO | ALL | BR | 3...
# 4   2025-03-31  SSP-L12 | CAPTACAO | CBO | FRIO | ALL | BR | 3...
# ..         ...                                                ...
# 624 2025-04-15  SSP-L12 | CAPTACAO | CBO | QUENTE | ALL | BR |...
# 625 2025-04-15  SSP-L12 | CAPTACAO | CBO | QUENTE | ALL | BR |...
# 626 2025-04-15  SSP-L12 | CAPTACAO | CBO | QUENTE | ALL | BR |...
# 627 2025-04-15  SSP-L12 | CAPTACAO | CBO | QUENTE | ALL | BR |...
# 628 2025-04-15  SSP-L12 | CAPTACAO | CBO | QUENTE | ALL | BR |...
#
#                                       utm medium               utm content  \
# 0      00 | AUTO | LAL | 1% | ENVOLVIMENTO IG 7D  ADS_003_ANUNCIO PETRO 03
# 1      00 | AUTO | LAL | 1% | ENVOLVIMENTO IG 7D  ADS_002_ANUNCIO PETRO 02
# 2      00 | AUTO | LAL | 1% | ENVOLVIMENTO IG 7D  ADS_001_ANUNCIO PETRO 01
# 3    00 | AUTO | LAL | 1%  | ENVOLVIMENTO IG 14D  ADS_003_ANUNCIO PETRO 03
# 4    00 | AUTO | LAL | 1%  | ENVOLVIMENTO IG 14D  ADS_002_ANUNCIO PETRO 02
# ..                                           ...                       ...
# 624       00 | AUTO | SALVOU + ENVIOU MSG | 365D  ADS_001_ANUNCIO PETRO 01
# 625               00 | AUTO | ENVOLVIMENTO | 90D  ADS_003_ANUNCIO PETRO 03
# 626               00 | AUTO | ENVOLVIMENTO | 90D  ADS_001_ANUNCIO PETRO 01
# 627               00 | AUTO | ENVOLVIMENTO | 14D  ADS_001_ANUNCIO PETRO 01
# 628               00 | AUTO | ENVOLVIMENTO | 14D  ADS_002_ANUNCIO PETRO 02
#
#        spend  impressions  actions_link_click  actions_landing_page_view
# 0     4004.0       2878.0                16.0                        1.0
# 1     8664.0       5862.0                41.0                        1.0
# 2    20466.0      17136.0               259.0                       20.0
# 3     7885.0       6254.0                30.0                        0.0
# 4     2032.0       1786.0                14.0                        1.0
# ..       ...          ...                 ...                        ...
# 624      4.0          5.0                 0.0                        0.0
# 625    854.0        670.0                 9.0                        7.0
# 626   1327.0        925.0                13.0                        8.0
# 627    169.0       1043.0                 9.0                        8.0
# 628   2057.0       1567.0                17.0                       16.0
#
# [629 rows x 8 columns]

# %%
df_compradores.rename(columns={'email contato': 'email'}, inplace=True)
df_compradores["email"] = df_compradores["email"].str.lower().str.strip()
df_compradores = df_compradores.drop_duplicates(subset='email', keep='first')

df_compradores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 593 entries, 0 to 592
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   email   593 non-null    object
# dtypes: object(1)
# memory usage: 4.8+ KB

# %%
df_pesquisa_compradores_l12 = df_pesquisa_captacao[
    df_pesquisa_captacao["email"].isin(df_compradores["email"])
].copy()

# %%
df_pesquisa_compradores_l12.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 195 entries, 12 to 27052
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   data                   195 non-null    datetime64[ns]
#  1   email                  195 non-null    object
#  2   idade                  195 non-null    object
#  3   nível                  195 non-null    object
#  4   situação profissional  195 non-null    object
#  5   renda                  195 non-null    object
#  6   escolaridade           195 non-null    object
#  7   duvida                 195 non-null    object
#  8   dificuldade            195 non-null    object
# dtypes: datetime64[ns](1), object(8)
# memory usage: 15.2+ KB

# %%
df_pesquisa_compradores_l12
# Out:
#             data                            email  idade     nível  \
# 12    2025-04-07    caroline.micaelle16@gmail.com  18-22  Superior
# 60    2025-04-07           helder170@yahoo.com.br  38-45   Técnica
# 270   2025-04-07           joaochodachi@gmail.com  28-32   Técnica
# 295   2025-04-07          mayconjean612@gmail.com  28-32   Técnica
# 309   2025-04-07               cidgmj79@gmail.com  46-52   Técnica
# ...          ...                              ...    ...       ...
# 26689 2025-04-16  espindolavitorandrade@gmail.com  23-27  Superior
# 26726 2025-04-16      felipebarboosa532@gmail.com  18-22   Técnica
# 26805 2025-04-18           davisouzamg1@gmail.com  23-27   Técnica
# 26875 2025-04-20      flavioraphaelli87@gmail.com  33-37   Técnica
# 27052 2025-04-30          tiagolima1967@gmail.com  33-37   Técnica
#
#                 situação profissional             renda  \
# 12     Funcionário de empresa privada  De 1.000 a 3.000
# 60     Funcionário de empresa privada  De 1.000 a 3.000
# 270    Funcionário de empresa privada  De 1.000 a 3.000
# 295                   Desempregado(a)  De 1.000 a 3.000
# 309    Funcionário de empresa privada  De 3.000 a 5.000
# ...                               ...               ...
# 26689                 Desempregado(a)      De 0 a 1.000
# 26726  Funcionário de empresa privada  De 1.000 a 3.000
# 26805  Funcionário de empresa privada  De 1.000 a 3.000
# 26875  Funcionário de empresa privada  De 1.000 a 3.000
# 27052  Funcionário de empresa privada  De 3.000 a 5.000
#
#                    escolaridade  \
# 12     Ensino superior completo
# 60        Ensino médio completo
# 270       Ensino médio completo
# 295    Ensino superior completo
# 309      Nível técnico completo
# ...                         ...
# 26689     Ensino médio completo
# 26726     Ensino médio completo
# 26805    Nível técnico completo
# 26875     Ensino médio completo
# 27052    Nível técnico completo
#
#                                                   duvida  \
# 12     A quais vagas posso concorrer tendo tecnólogo ...
# 60     Tenho o curso técnico em contabilidade servi p...
# 270                Em qual cidade irei fazer o concurso?
# 295                            Quando vai sair o edital
# 309                                              A prova
# ...                                                  ...
# 26689                  Consigo fazer sem ter um técnico
# 26726                                          Matérias
# 26805                                          Formação
# 26875  Qual o melhor curso técnico para fazer? E qual...
# 27052          Como estudar com eficiência para a prova
#
#                         dificuldade
# 12                            Tempo
# 60                     Memorização
# 270          Não sei o que estudar
# 295                           Foco
# 309                          Tempo
# ...                             ...
# 26689                         Tempo
# 26726                      Nenhuma
# 26805                       Ensino
# 26875                Procrastinação
# 27052  Jornada de trabalho noturno
#
# [195 rows x 9 columns]

# %%
df_compradores_nao_respondentes = df_compradores[
    ~df_compradores["email"].isin(df_pesquisa_captacao["email"])
].copy()

# %%
df_compradores_nao_respondentes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 398 entries, 0 to 591
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   email   398 non-null    object
# dtypes: object(1)
# memory usage: 6.2+ KB

# %%
df_pesquisa_captacao['lancamentos'] = 'SSP-L12'
df_pesquisa_captacao.loc[df_pesquisa_captacao["data"] >= pd.Timestamp("2025-04-30"), "lancamentos"] = "SSP-L13"

df_pesquisa_compradores_l12['lancamentos'] = 'SSP-L12'

# %%
# Colunas de UTM que vamos trazer
colunas_utm = ['utm_source', 'utm_campaign', 'utm_medium', 'utm_content']

# Fazer o merge trazendo as UTMs para df_pesquisa_captacao
df_pesquisa_captacao = df_pesquisa_captacao.merge(
    df_leads_trafego[['email'] + colunas_utm],
    on='email',
    how='left'  # Mantém todas as respostas da pesquisa, mesmo se não tiver UTM
)

# Fazer o merge trazendo as UTMs para df_pesquisa_compradores_l12
df_pesquisa_compradores_l12 = df_pesquisa_compradores_l12.merge(
    df_leads_trafego[['email'] + colunas_utm],
    on='email',
    how='left'
)

# %%
df_pesquisa_captacao
# Out:
#             data                           email  idade     nível  \
# 0     2025-04-07        manoeltarsis22@gmail.com  33-37   Técnica
# 1     2025-04-07  geovanarodrigues0106@gmail.com  23-27   Técnica
# 2     2025-04-07              jj272824@gmail.com  18-22  Superior
# 3     2025-04-07       iuriguerreiro45@gmail.com  28-32   Técnica
# 4     2025-04-07    stevaogabrieli2020@gmail.com  18-22   Técnica
# ...          ...                             ...    ...       ...
# 27499 2025-05-01     jonathanfelippe85@gmail.com  18-22   Técnica
# 27500 2025-05-01   marcelo_frameschi@hotmail.com  46-52  Superior
# 27501 2025-05-01        fs081973304059@gmail.com  23-27  Superior
# 27502 2025-05-01    wesleyantonichen91@gmail.com  28-32   Técnica
# 27503 2025-05-01             guhki9535@gmail.com  23-27   Técnica
#
#                 situação profissional                  renda  \
# 0                            Autônomo       De 1.000 a 3.000
# 1                     Desempregado(a)  Estou desempregado(a)
# 2                     Desempregado(a)  Estou desempregado(a)
# 3                     Desempregado(a)  Estou desempregado(a)
# 4                            Autônomo  Estou desempregado(a)
# ...                               ...                    ...
# 27499                 Desempregado(a)  Estou desempregado(a)
# 27500                        Autônomo       De 3.000 a 5.000
# 27501                        Autônomo           De 0 a 1.000
# 27502                 Desempregado(a)       De 1.000 a 3.000
# 27503  Funcionário de empresa privada       De 1.000 a 3.000
#
#                      escolaridade  \
# 0           Ensino médio completo
# 1      Ensino superior incompleto
# 2           Ensino médio completo
# 3          Nível técnico completo
# 4           Ensino médio completo
# ...                           ...
# 27499       Ensino médio completo
# 27500    Ensino superior completo
# 27501       Ensino médio completo
# 27502       Ensino médio completo
# 27503       Ensino médio completo
#
#                                                   duvida          dificuldade  \
# 0                         O que preciso pra ser aprovado                Tempo
# 1                                                      .     Separa material
# 2                      O quão difícil é conseguir passar             Nenhuma
# 3         Em qual lugar do Brasil pode fazer o concurso?                Tempo
# 4                         Se precisa de ensino superior               Nenhuma
# ...                                                  ...                  ...
# 27499                              Será q tenho chance ?             Nenhuma
# 27500                   Período e condições de trabalho              Horário
# 27501          Garanti minha vaga e crece com a empresa              Nenhuma
# 27502  Como entrar em contato e ter uma oportunidade ...      Seria horários
# 27503                                                  1  Não há dificuldade
#
#       lancamentos    utm_source  \
# 0         SSP-L12  Facebook-Ads
# 1         SSP-L12  Facebook-Ads
# 2         SSP-L12  Facebook-Ads
# 3         SSP-L12  Facebook-Ads
# 4         SSP-L12  Facebook-Ads
# ...           ...           ...
# 27499     SSP-L13  Facebook-Ads
# 27500     SSP-L13  Facebook-Ads
# 27501     SSP-L13  Facebook-Ads
# 27502     SSP-L13  Facebook-Ads
# 27503     SSP-L13           NaN
#
#                                             utm_campaign  \
# 0      SSP-L12 | CAPTACAO | CBO | QUENTE | ALL | BR |...
# 1      SSP-L12 | CAPTACAO | CBO | FRIO | ALL | BR | 3...
# 2      SSP-L12 | CAPTACAO | CBO | QUENTE | ALL | BR |...
# 3      SSP-L12 | CAPTACAO | CBO | QUENTE | ALL | BR |...
# 4      SSP-L12 | CAPTACAO | CBO | QUENTE | ALL | BR |...
# ...                                                  ...
# 27499  SSP-L13 | CAPTACAO | CBO | FRIO | ALL | BR | 3...
# 27500  SSP-L13 | CAPTACAO | ABO | FRIO | ALL | BR | 3...
# 27501  SSP-L13 | CAPTACAO | CBO | FRIO | ALL | BR | 3...
# 27502  SSP-L13 | CAPTACAO | CBO | FRIO | ALL | BR | 3...
# 27503                                                NaN
#
#                                           utm_medium  \
# 0          00 | AUTO | MIX DE PUBLICOS | CRIATIVO 07
# 1          00 | AUTO | LAL | 1% | ENVOLVIMENTO IG 7D
# 2                     00 | AUTO | ENVOLVIMENTO | 90D
# 3                     00 | AUTO | ENVOLVIMENTO | 30D
# 4          00 | AUTO | MIX DE PUBLICOS | CRIATIVO 08
# ...                                              ...
# 27499      00 | AUTO | LAL | 1% | ENVOLVIMENTO IG 7D
# 27500    00 | AUTO |  LAL | 1% | ENV 7D | CRIATIVO 4
# 27501    00 | AUTO | LAL | 1%  | ENVOLVIMENTO IG 14D
# 27502  00 | AUTO | LAL | 1%  | ENVOLVIMENTO IG | 30D
# 27503                                            NaN
#
#                         utm_content
# 0          ADS_007_ANUNCIO PETRO 07
# 1          ADS_001_ANUNCIO PETRO 01
# 2          ADS_006_ANUNCIO PETRO 06
# 3          ADS_001_ANUNCIO PETRO 01
# 4          ADS_008_ANUNCIO PETRO 08
# ...                             ...
# 27499  ADS_VID_002_ANUNCIO PETRO 02
# 27500  ADS_VID_004_ANUNCIO PETRO 04
# 27501  ADS_VID_002_ANUNCIO PETRO 02
# 27502  ADS_VID_002_ANUNCIO PETRO 02
# 27503                           NaN
#
# [27504 rows x 14 columns]

# %%
df_pesquisa_compradores_l12
# Out:
#           data                            email  idade     nível  \
# 0   2025-04-07    caroline.micaelle16@gmail.com  18-22  Superior
# 1   2025-04-07           helder170@yahoo.com.br  38-45   Técnica
# 2   2025-04-07           joaochodachi@gmail.com  28-32   Técnica
# 3   2025-04-07          mayconjean612@gmail.com  28-32   Técnica
# 4   2025-04-07               cidgmj79@gmail.com  46-52   Técnica
# ..         ...                              ...    ...       ...
# 190 2025-04-16  espindolavitorandrade@gmail.com  23-27  Superior
# 191 2025-04-16      felipebarboosa532@gmail.com  18-22   Técnica
# 192 2025-04-18           davisouzamg1@gmail.com  23-27   Técnica
# 193 2025-04-20      flavioraphaelli87@gmail.com  33-37   Técnica
# 194 2025-04-30          tiagolima1967@gmail.com  33-37   Técnica
#
#               situação profissional             renda  \
# 0    Funcionário de empresa privada  De 1.000 a 3.000
# 1    Funcionário de empresa privada  De 1.000 a 3.000
# 2    Funcionário de empresa privada  De 1.000 a 3.000
# 3                   Desempregado(a)  De 1.000 a 3.000
# 4    Funcionário de empresa privada  De 3.000 a 5.000
# ..                              ...               ...
# 190                 Desempregado(a)      De 0 a 1.000
# 191  Funcionário de empresa privada  De 1.000 a 3.000
# 192  Funcionário de empresa privada  De 1.000 a 3.000
# 193  Funcionário de empresa privada  De 1.000 a 3.000
# 194  Funcionário de empresa privada  De 3.000 a 5.000
#
#                  escolaridade  \
# 0    Ensino superior completo
# 1       Ensino médio completo
# 2       Ensino médio completo
# 3    Ensino superior completo
# 4      Nível técnico completo
# ..                        ...
# 190     Ensino médio completo
# 191     Ensino médio completo
# 192    Nível técnico completo
# 193     Ensino médio completo
# 194    Nível técnico completo
#
#                                                 duvida  \
# 0    A quais vagas posso concorrer tendo tecnólogo ...
# 1    Tenho o curso técnico em contabilidade servi p...
# 2                Em qual cidade irei fazer o concurso?
# 3                            Quando vai sair o edital
# 4                                              A prova
# ..                                                 ...
# 190                  Consigo fazer sem ter um técnico
# 191                                          Matérias
# 192                                          Formação
# 193  Qual o melhor curso técnico para fazer? E qual...
# 194          Como estudar com eficiência para a prova
#
#                       dificuldade lancamentos    utm_source  \
# 0                           Tempo     SSP-L12       Youtube
# 1                    Memorização      SSP-L12  Facebook-Ads
# 2          Não sei o que estudar      SSP-L12       Youtube
# 3                           Foco      SSP-L12  Facebook-Ads
# 4                          Tempo      SSP-L12  Facebook-Ads
# ..                            ...         ...           ...
# 190                         Tempo     SSP-L12           NaN
# 191                      Nenhuma      SSP-L12       Youtube
# 192                       Ensino      SSP-L12  Facebook-Ads
# 193                Procrastinação     SSP-L12           NaN
# 194  Jornada de trabalho noturno      SSP-L12  Facebook-Ads
#
#                                           utm_campaign  \
# 0
# 1    SSP-L12 | CAPTACAO | ABO | FRIO | ALL | BR | 0...
# 2
# 3    SSP-L12 | CAPTACAO | CBO | QUENTE | ALL | BR |...
# 4    SSP-L12 | CAPTACAO | CBO | FRIO | ALL | BR | 3...
# ..                                                 ...
# 190                                                NaN
# 191
# 192  SSP-L12 | CAPTACAO | CBO | FRIO | ALL | BR | 3...
# 193                                                NaN
# 194  SSP-L13 | CAPTACAO | CBO | QUENTE | ALL | BR |...
#
#                                        utm_medium  \
# 0                                       Descricao
# 1    00 | AUTO |  LAL | 1% | ENV 7D | CRIATIVO 10
# 2                                       Descricao
# 3                  00 | AUTO | ENVOLVIMENTO | 90D
# 4     00 | AUTO | LAL | 1%  | ENVOLVIMENTO IG 14D
# ..                                            ...
# 190                                           NaN
# 191                                     Descricao
# 192   00 | AUTO | LAL | 1%  | ENVOLVIMENTO IG 14D
# 193                                           NaN
# 194                00 | AUTO | ENVOLVIMENTO | 30D
#
#                       utm_content
# 0
# 1        ADS_010_ANUNCIO PETRO 10
# 2
# 3        ADS_007_ANUNCIO PETRO 07
# 4        ADS_001_ANUNCIO PETRO 01
# ..                            ...
# 190                           NaN
# 191
# 192      ADS_007_ANUNCIO PETRO 07
# 193                           NaN
# 194  ADS_VID_002_ANUNCIO PETRO 02
#
# [195 rows x 14 columns]

# %%
# Definir as colunas UTM
colunas_utms = ['utm_source', 'utm_campaign', 'utm_medium', 'utm_content']

# Contar quantas linhas têm todas as UTMs como NaN
qtd_todas_utms_nan = df_pesquisa_compradores_l12[colunas_utms].isna().all(axis=1).sum()

print(f"Quantidade de linhas com TODAS as UTMs NaN: {qtd_todas_utms_nan}")
# Out:
# Quantidade de linhas com TODAS as UTMs NaN: 20

# %%
"""
model = SentenceTransformer("all-MiniLM-L6-v2")

# Mapas distintos por coluna
mapeamentos = {
    'problema_aprender': mapeamento_problema_aprender,
    'profissao': mapeamento_profissoes,
    'fala_outro_idioma': mapeamento_outros_idiomas,
    'motivo_fluencia_espanhol': mapeamento_motivo_fluencia,
    'escolaridade': mapeamento_escolaridade
}

for coluna, mapeamento in mapeamentos.items():
    nome_coluna_categoria = f"{coluna}_categoria"

    # Expandir mapeamento para esta coluna
    mapeamento_expandido, mapeamento_embeddings = preparar_para_categoria(mapeamento, model)

    # Categorização com o mapeamento certo
    df_pesquisa_captacao_lancamentos.loc[:, nome_coluna_categoria] = categorizar_coluna_batch(
        df_pesquisa_captacao_lancamentos[coluna],
        mapeamento_expandido,
        mapeamento_embeddings,
        model,
        threshold=0.6,
        desc=coluna
    )
"""
# Out:
# '\nmodel = SentenceTransformer("all-MiniLM-L6-v2")\n\n# Mapas distintos por coluna\nmapeamentos = {\n    \'problema_aprender\': mapeamento_problema_aprender,\n    \'profissao\': mapeamento_profissoes,\n    \'fala_outro_idioma\': mapeamento_outros_idiomas,\n    \'motivo_fluencia_espanhol\': mapeamento_motivo_fluencia,\n    \'escolaridade\': mapeamento_escolaridade\n}\n\nfor coluna, mapeamento in mapeamentos.items():\n    nome_coluna_categoria = f"{coluna}_categoria"\n\n    # Expandir mapeamento para esta coluna\n    mapeamento_expandido, mapeamento_embeddings = preparar_para_categoria(mapeamento, model)\n\n    # Categorização com o mapeamento certo\n    df_pesquisa_captacao_lancamentos.loc[:, nome_coluna_categoria] = categorizar_coluna_batch(\n        df_pesquisa_captacao_lancamentos[coluna],\n        mapeamento_expandido,\n        mapeamento_embeddings,\n        model,\n        threshold=0.6,\n        desc=coluna\n    )\n'

# %%
"""# Exibir strings completas
pd.set_option("display.max_colwidth", None)

# Colunas categorizadas e respectivas colunas originais
categorias = {
    "problema_aprender": "problema_aprender_categoria",
    "profissao": "profissao_categoria",
    "fala_outro_idioma": "fala_outro_idioma_categoria",
    "motivo_fluencia_espanhol": "motivo_fluencia_espanhol_categoria",
    "escolaridade": "escolaridade_categoria"
}

# Categorias problemáticas
categorias_problema = ["Outros"]

# Loop para filtrar e exibir como DataFrame formatado
for original_col, categoria_col in categorias.items():
    for problema in categorias_problema:
        print(f"\n=== Valores de '{original_col}' categorizados como '{problema}' ===")

        filtro = df_pesquisa_captacao_lancamentos[categoria_col] == problema
        valores = df_pesquisa_captacao_lancamentos.loc[filtro, original_col].value_counts()

        # Envolver cada valor com aspas
        valores.index = [f'"{val}"' for val in valores.index]

        # Converter para DataFrame para visualização completa
        valores_df = valores.reset_index().head(300)
        valores_df.columns = ['valor_original', 'frequencia']

        # Exibir o resultado completo
        print(valores_df.to_string(index=False))
"""
# Out:
# '# Exibir strings completas\npd.set_option("display.max_colwidth", None)\n\n# Colunas categorizadas e respectivas colunas originais\ncategorias = {\n    "problema_aprender": "problema_aprender_categoria",\n    "profissao": "profissao_categoria",\n    "fala_outro_idioma": "fala_outro_idioma_categoria",\n    "motivo_fluencia_espanhol": "motivo_fluencia_espanhol_categoria",\n    "escolaridade": "escolaridade_categoria"\n}\n\n# Categorias problemáticas\ncategorias_problema = ["Outros"]\n\n# Loop para filtrar e exibir como DataFrame formatado\nfor original_col, categoria_col in categorias.items():\n    for problema in categorias_problema:\n        print(f"\n=== Valores de \'{original_col}\' categorizados como \'{problema}\' ===")\n\n        filtro = df_pesquisa_captacao_lancamentos[categoria_col] == problema\n        valores = df_pesquisa_captacao_lancamentos.loc[filtro, original_col].value_counts()\n\n        # Envolver cada valor com aspas\n        valores.index = [f\'"{val}"\' for val in valores.index]\n\n        # Converter para DataFrame para visualização completa\n        valores_df = valores.reset_index().head(300)\n        valores_df.columns = [\'valor_original\', \'frequencia\']\n\n        # Exibir o resultado completo\n        print(valores_df.to_string(index=False))\n'

# %%
"""df_pesquisa_captacao_lancamentos = df_pesquisa_captacao_lancamentos.drop([
    'profissao',
    'fala_outro_idioma',
    'motivo_fluencia_espanhol',
    'escolaridade',
    'problema_aprender'
], axis=1, errors='ignore')
"""
# Out:
# "df_pesquisa_captacao_lancamentos = df_pesquisa_captacao_lancamentos.drop([\n    'profissao',\n    'fala_outro_idioma',\n    'motivo_fluencia_espanhol',\n    'escolaridade',\n    'problema_aprender'\n], axis=1, errors='ignore')\n"

# %%
from gspread_dataframe import set_with_dataframe
from datetime import datetime

# Carrega as variáveis de ambiente
load_dotenv()

# Pega o caminho de forma segura
credenciais_path = os.getenv("GOOGLE_CREDENTIALS_PATH")

# === Escopos de acesso ===
scopes = [
    "https://www.googleapis.com/auth/spreadsheets",
    "https://www.googleapis.com/auth/drive"
]

# === Autenticar ===
creds = service_account.Credentials.from_service_account_file(
    credenciais_path,
    scopes=scopes
)
client = gspread.authorize(creds)

# === Função para criar nova planilha e carregar dados ===
def criar_planilha_e_enviar(df, nome_base):
    nome_final = nome_base
    
    # Cria nova planilha
    planilha = client.create(nome_final)
    
    # Compartilha com seu e-mail pessoal (aqui você coloca o seu)
    planilha.share('camilobf2@gmail.com', perm_type='user', role='writer')  # <<< Trocar pelo seu email do Gmail

    # Preenche a primeira aba
    aba = planilha.sheet1
    aba.update_title("Dados")
    set_with_dataframe(aba, df)
    
    print(f"✅ Nova planilha criada: {nome_final}")
    print(f"🔗 Link: https://docs.google.com/spreadsheets/d/{planilha.id}/edit")

# === Geração dos arquivos ===
#criar_planilha_e_enviar(df_pesquisa_captacao, "pesquisa_captacao")
#criar_planilha_e_enviar(df_pesquisa_compradores_l12, "pesquisa_aluno")
#criar_planilha_e_enviar(df_leads_invest_trafego, "invest_trafego")

# %%
# === Função para atualizar uma planilha existente ===
def atualizar_planilha_existente(df: pd.DataFrame, sheet_id: str, aba_nome: str = "Dados"):
    """
    Atualiza uma aba específica de uma planilha no Google Sheets.
    
    - df: DataFrame com os dados que serão enviados
    - sheet_id: ID da planilha (o que vem na URL depois de "/d/")
    - aba_nome: Nome da aba que será atualizada (default: 'Dados')
    """
    try:
        planilha = client.open_by_key(sheet_id)
        try:
            aba = planilha.worksheet(aba_nome)
        except gspread.WorksheetNotFound:
            aba = planilha.add_worksheet(title=aba_nome, rows="1000", cols="20")
        
        aba.clear()  # Limpa dados antigos
        set_with_dataframe(aba, df)
        
        print(f"✅ Planilha atualizada: https://docs.google.com/spreadsheets/d/{sheet_id}/edit")
    except Exception as e:
        print(f"❌ Erro ao atualizar a planilha: {e}")

# === IDs das planilhas (FIXOS, preencha certinho aqui) ===
id_pesquisa_captacao = "1ukLwu8SoP0U3uirB6w1Ca3TPEITY50c558xNUUN3kj4"
id_pesquisa_aluno = "1GDCAa1fiflDIBnRY9rrdY9ghKwS6DPzxIG9FYGZEsQU"
id_invest_trafego = "1477LAemTkMN1YTFdRJkLMaDLPZEiJ3vvtqwduemHXD4"


# === Atualizar todas as planilhas ===
atualizar_planilha_existente(df_pesquisa_captacao, id_pesquisa_captacao)
atualizar_planilha_existente(df_pesquisa_compradores_l12, id_pesquisa_aluno)
atualizar_planilha_existente(df_leads_invest_trafego, id_invest_trafego)
# Out:
# ✅ Planilha atualizada: https://docs.google.com/spreadsheets/d/1ukLwu8SoP0U3uirB6w1Ca3TPEITY50c558xNUUN3kj4/edit
# ✅ Planilha atualizada: https://docs.google.com/spreadsheets/d/1GDCAa1fiflDIBnRY9rrdY9ghKwS6DPzxIG9FYGZEsQU/edit
# ✅ Planilha atualizada: https://docs.google.com/spreadsheets/d/1477LAemTkMN1YTFdRJkLMaDLPZEiJ3vvtqwduemHXD4/edit

# %%
colunas_excluir = ["data", "email"]

for coluna in df_pesquisa_captacao.columns:
    if coluna not in colunas_excluir:
        print(f"\nColuna: {coluna}")
        print(df_pesquisa_captacao[coluna].value_counts(dropna=False))
# Out:
# Coluna: idade
# idade
# 23-27         5862
# 18-22         5515
# 28-32         4821
# 38-45         4513
# 33-37         3867
# 46-52         2074
# 53 ou mais     852
# Name: count, dtype: int64
#
# Coluna: nível
# nível
# Técnica     20909
# Superior     6595
# Name: count, dtype: int64
#
# Coluna: situação profissional
# situação profissional
# Funcionário de empresa privada                          11693
# Autônomo                                                 6485
# Desempregado(a)                                          6316
# Funcionário público                                      1969
# Empresário                                                572
# Já sou funcionário terceirizado do sistema Petrobras      469
# Name: count, dtype: int64
#
# Coluna: renda
# renda
# De 1.000 a 3.000         13797
# De 3.000 a 5.000          5074
# De 0 a 1.000              3524
# Estou desempregado(a)     3217
# De 5.000 a 10.000         1628
# Mais de 10.000             264
# Name: count, dtype: int64
#
# Coluna: escolaridade
# escolaridade
# Ensino médio completo         15815
# Ensino superior completo       4141
# Ensino superior incompleto     3753
# Nível técnico completo         2687
# Nível técnico incompleto       1108
# Name: count, dtype: int64
#
# Coluna: duvida
# duvida
# Nenhuma                                                      375
# 1                                                            334
# 10                                                           261
# Salário                                                      177
# Nenhuma                                                      171
#                                                             ...
# Só a distância das provas                                      1
# Como me tornar funcionário da Petrobrás                        1
# Néi nhuma                                                      1
# Como consigo trabalhar lar no sistema Petrobras                1
# Como entrar em contato e ter uma oportunidade de emprego       1
# Name: count, Length: 17159, dtype: int64
#
# Coluna: dificuldade
# dificuldade
# Tempo                                                 3621
# Nenhuma                                               2031
# Tempo                                                 1896
# Concentração                                          1047
# Nenhuma                                                970
#                                                       ...
# Caminho correto                                          1
# ó tempo pouco, é tenho dificuldade na teoria 🤦🏿‍♂️       1
# Não tenho dificuldade nn                                 1
# Compreende conteúdos rápido                              1
# Seria horários                                           1
# Name: count, Length: 8014, dtype: int64
#
# Coluna: lancamentos
# lancamentos
# SSP-L12    26244
# SSP-L13     1260
# Name: count, dtype: int64
#
# Coluna: utm_source
# utm_source
# Facebook-Ads    18426
# NaN              3835
# Instagram        3222
# Tiktok           1408
# Youtube           613
# Name: count, dtype: int64
#
# Coluna: utm_campaign
# utm_campaign
# SSP-L12 | CAPTACAO | CBO | QUENTE | ALL | BR | 03-04-2025 | ENVOLVIMENTO                             5701
#                                                                                                      5243
# SSP-L12 | CAPTACAO | CBO | FRIO | ALL | BR | 31-03-25 | Lookalike e Interesses                       4201
# NaN                                                                                                  3835
# SSP-L12 | CAPTACAO | ABO | FRIO | ALL | BR | 04-04-2025 | Teste de criativos                         3490
# SSP-L12 | CAPTACAO | CBO | QUENTE | ALL | BR | 03-04-2025 | Teste de criativos                       2856
# SSP-L12 | CAPTACAO | ABO | QUENTE | ALL | BR | 03-04-2025 | Teste de criativos                        863
# SSP-L13 | CAPTACAO | CBO | FRIO | ALL | BR | 30-05-25 | Lookalike e Interesses                        684
# {{campaign.name}}                                                                                     288
# SSP-L13 | CAPTACAO | ABO | FRIO | ALL | BR | 30-04-25 | Teste de criativos                            140
# SSP-L13 | CAPTACAO | CBO | QUENTE | ALL | BR | 30-04-2025 | ENVOLVIMENTO                               85
# SSP-L12 | CAPTACAO | CBO | FRIO | ALL | BR | 31-03-25 | Lookalike e Interesses  | Teste de página      40
# SSP-L12 | CAPTACAO | CBO | QUENTE | ALL | BR | 03-04-2025 | LEADS                                      34
# SSP-L12 | CAPTACAO | CBO | QUENTE | ALL | BR | 03-04-2025 |                                            25
# SSP-L12 | CAPTACAO | CBO | FRIO | ALL | BR | 03-04-25 | Interesses                                      9
# SSP-L12 | CAPTACAO | ABO | FRIO | ALL | BR | 31-03-25 | LL | TESTE                                      8
# SSP-L13 | CAPTACAO | CBO | FRIO | ALL | BR | 30-04-25 | Interesses                                      1
# SSP-L13 | CAPTACAO | CBO | QUENTE | ALL | BR | 30-04-2025 | LEADS                                       1
# Name: count, dtype: int64
#
# Coluna: utm_medium
# utm_medium
# Bio                                                  4240
# NaN                                                  3835
# 00 | AUTO | ENVOLVIMENTO | 90D                       2614
# 00 | AUTO | ENVOLVIMENTO | 30D                       1856
# 00 | AUTO | LAL | 1% | ENVOLVIMENTO IG 7D            1525
# 00 | AUTO | LAL | 1%  | ENVOLVIMENTO IG 14D          1380
# 00 | AUTO | ENVOLVIMENTO | 14D                       1307
# 00 | AUTO | LAL | 1%  | INTIATE CHECKOUT | 180D      1275
# 00 | AUTO |  LAL | 1% | ENV 7D | CRIATIVO 07         1036
# 00 | AUTO | LAL | 1% | ENV 7D | CRIATIVO 06          1025
# 00 | AUTO | LAL | 1% | ENV 7D | CRIATIVO 11          1025
# 00 | AUTO | MIX DE PUBLICOS | CRIATIVO 07             815
# 00 | AUTO | LAL | 1%  | ENVOLVIMENTO IG | 30D         744
# 00 | AUTO | MIX DE PUBLICOS | CRIATIVO 08             738
# Descricao                                             613
# 00 | AUTO | MIX DE PUBLICOS | CRIATIVO 05             564
# 00 | AUTO | MIX DE PUBLICOS | CRIATIVO 06             550
# 00 | AUTO |  LAL | 1% | ENV 7D | CRIATIVO 10          444
# Stories                                               390
# 00 | AUTO |  LAL | 1% | ENV 7D | CRIATIVO 05          381
# 00 | AUTO |  LAL | 1% | ENV 7D | CRIATIVO 08          348
# {{adset.name}}                                        288
# 00 | AUTO | MIX DE PUBLICOS | CRIATIVO 01              86
# 00 | AUTO | LAL | 1% | ENV 7D | CRIATIVO 04            72
# 00 | AUTO | MIX DE PUBLICOS | CRIATIVO 02              56
# 00 | AUTO | MIX DE PUBLICOS | CRIATIVO 04              44
# 00 | AUTO | LAL | 1% | ENV 7D | CRIATIVO 2             30
# 00 | AUTO | LAL | 1% | ENV 7D | CRIATIVO 8             26
# 00 | AUTO | PAGEVIEW | 14D                             18
# 00 | AUTO | LAL | 1% | ENV 7D  | CRIATIVO 6            18
# 00 | AUTO |  LAL | 1% | ENV 7D | CRIATIVO 4            18
# 00 | AUTO | SEGUIDORES                                 16
# 00 | AUTO |  LAL | 1% | ENV 7D | CRIATIVO 01           14
# 00 | AUTO | PAGEVIEW | 30D                             13
# 00 | AUTO | LAL | 1% | ENV 7D | CRIATIVO 1             13
# 00 | AUTO | LISTA | LEADS GERAL                        12
# 00 | AUTO | LAL | 1% | ENV 7D | CRIATIVO 7             11
# 00 | AUTO | INTERESSES | PETROBRAS                     11
# 00 | AUTO | LAL | 1% | ENV 7D | CRIATIVO 5              9
# 00 | AUTO | SALVOU + ENVIOU MSG | 365D                  9
# 00 | AUTO | LAL | 1% | ENV 7D  | CRIATIVO 9             9
# 00 | AUTO | LAL | 1% | ENV 7D | CRIATIVO 3              6
# 00 | AUTO | LAL | 1% | ENVOLVIMENTO | LEADS GERAL       5
# 00 | AUTO | LAL | 1% | ENV 7D | CRIATIVO 09             5
# 00 | AUTO | LAL | 1% | ENVOLVIMENTO | 14D               3
# 00 | AUTO | LAL | 1% | ENV 7D | CRIATIVO 03             2
# 00 | AUTO | MIX DE PUBLICOS | CRIATIVO 09               2
# 00 | AUTO | MIX DE PUBLICOS | CRIATIVO 03               1
# 00 | AUTO | LAL | 1% | ENV 7D | CRIATIVO 12             1
# 00 | AUTO | CHECKOUT | 180D                             1
# Name: count, dtype: int64
#
# Coluna: utm_content
# utm_content
# ADS_006_ANUNCIO PETRO 06        5937
# ADS_007_ANUNCIO PETRO 07        5249
#                                 5243
# NaN                             3835
# ADS_008_ANUNCIO PETRO 08        2692
# ADS_011_ANUNCIO PETRO 11        1025
# ADS_005_ANUNCIO PETRO 05         945
# ADS_VID_002_ANUNCIO PETRO 02     773
# ADS_001_ANUNCIO PETRO 01         601
# ADS_010_ANUNCIO PETRO 10         483
# {{ad.name}}                      288
# ADS_004_ANUNCIO PETRO 04         116
# ADS_002_ANUNCIO PETRO 02         112
# ADS_003_ANUNCIO PETRO 03          51
# ADS_VID_004_ANUNCIO PETRO 04      29
# ADS_VID_008_ANUNCIO PETRO 08      26
# ADS_VID_001_ANUNCIO PETRO 01      22
# ADS_VID_006_ANUNCIO PETRO 06      18
# ADS_VID_003_ANUNCIO PETRO 03      13
# ADS_VID_007_ANUNCIO PETRO 07      11
# ADS_VID_005_ANUNCIO PETRO 05      10
# ADS_VID_008_ANUNCIO PETRO 09       9
# ADS_009_ANUNCIO PETRO 09           7
# AD_001_ ANUNCIO PETRO 01           5
# AD_002_ ANUNCIO PETRO 02           3
# ADS_012_ANUNCIO PETRO 12           1
# Name: count, dtype: int64

# %%
colunas_excluir = ["data", "email"]

for coluna in df_pesquisa_compradores_l12.columns:
    if coluna not in colunas_excluir:
        print(f"\nColuna: {coluna}")
        print(df_pesquisa_compradores_l12[coluna].value_counts(dropna=False))
# Out:
# Coluna: idade
# idade
# 23-27         49
# 38-45         35
# 28-32         35
# 33-37         31
# 46-52         22
# 18-22         17
# 53 ou mais     6
# Name: count, dtype: int64
#
# Coluna: nível
# nível
# Técnica     164
# Superior     31
# Name: count, dtype: int64
#
# Coluna: situação profissional
# situação profissional
# Funcionário de empresa privada                          99
# Desempregado(a)                                         39
# Autônomo                                                33
# Empresário                                              12
# Funcionário público                                     10
# Já sou funcionário terceirizado do sistema Petrobras     2
# Name: count, dtype: int64
#
# Coluna: renda
# renda
# De 1.000 a 3.000         79
# De 3.000 a 5.000         55
# De 5.000 a 10.000        27
# Estou desempregado(a)    21
# De 0 a 1.000             10
# Mais de 10.000            3
# Name: count, dtype: int64
#
# Coluna: escolaridade
# escolaridade
# Ensino médio completo         72
# Ensino superior completo      61
# Nível técnico completo        39
# Ensino superior incompleto    21
# Nível técnico incompleto       2
# Name: count, dtype: int64
#
# Coluna: duvida
# duvida
# O que estudar                                                                        5
# Como passar                                                                          3
# O que estudar                                                                        3
# Como estudar                                                                         2
# Nenhuma                                                                              2
#                                                                                     ..
# profissão a seguir                                                                   1
# Faz tempo que não estudo. Será que ainda dá tempo pra retomar os estudos?            1
# Se e difícil passar na prova                                                         1
# minha dúvida maior e sobre as horas trabalhadas e como é a trajetória na empresa     1
# Como estudar com eficiência para a prova                                             1
# Name: count, Length: 181, dtype: int64
#
# Coluna: dificuldade
# dificuldade
# Tempo                           25
# Concentração                    16
# Tempo                           10
# Nenhuma                          5
# Disciplina                       5
#                                 ..
# Paciencia                        1
# Foco e disciplina                1
# .                                1
# Saber oq vai cair na prova       1
# Jornada de trabalho noturno      1
# Name: count, Length: 124, dtype: int64
#
# Coluna: lancamentos
# lancamentos
# SSP-L12    195
# Name: count, dtype: int64
#
# Coluna: utm_source
# utm_source
# Facebook-Ads    90
# Instagram       37
# Youtube         35
# NaN             20
# Tiktok          13
# Name: count, dtype: int64
#
# Coluna: utm_campaign
# utm_campaign
#                                                                                                      85
# SSP-L12 | CAPTACAO | CBO | QUENTE | ALL | BR | 03-04-2025 | ENVOLVIMENTO                             43
# NaN                                                                                                  20
# SSP-L12 | CAPTACAO | CBO | QUENTE | ALL | BR | 03-04-2025 | Teste de criativos                       16
# SSP-L12 | CAPTACAO | ABO | FRIO | ALL | BR | 04-04-2025 | Teste de criativos                         13
# SSP-L12 | CAPTACAO | CBO | FRIO | ALL | BR | 31-03-25 | Lookalike e Interesses                        7
# SSP-L12 | CAPTACAO | ABO | QUENTE | ALL | BR | 03-04-2025 | Teste de criativos                        5
# SSP-L12 | CAPTACAO | ABO | FRIO | ALL | BR | 31-03-25 | LL | TESTE                                    2
# SSP-L12 | CAPTACAO | CBO | QUENTE | ALL | BR | 03-04-2025 | LEADS                                     1
# {{campaign.name}}                                                                                     1
# SSP-L12 | CAPTACAO | CBO | FRIO | ALL | BR | 31-03-25 | Lookalike e Interesses  | Teste de página     1
# SSP-L13 | CAPTACAO | CBO | QUENTE | ALL | BR | 30-04-2025 | ENVOLVIMENTO                              1
# Name: count, dtype: int64
#
# Coluna: utm_medium
# utm_medium
# Bio                                                  44
# Descricao                                            35
# NaN                                                  20
# 00 | AUTO | ENVOLVIMENTO | 90D                       20
# 00 | AUTO | ENVOLVIMENTO | 30D                       15
# 00 | AUTO | ENVOLVIMENTO | 14D                        9
# Stories                                               6
# 00 | AUTO | LAL | 1% | ENV 7D | CRIATIVO 11           6
# 00 | AUTO | LAL | 1%  | ENVOLVIMENTO IG 14D           4
# 00 | AUTO | MIX DE PUBLICOS | CRIATIVO 08             4
# 00 | AUTO |  LAL | 1% | ENV 7D | CRIATIVO 05          4
# 00 | AUTO | MIX DE PUBLICOS | CRIATIVO 07             4
# 00 | AUTO |  LAL | 1% | ENV 7D | CRIATIVO 08          3
# 00 | AUTO |  LAL | 1% | ENV 7D | CRIATIVO 07          3
# 00 | AUTO | LAL | 1%  | ENVOLVIMENTO IG | 30D         3
# 00 | AUTO | MIX DE PUBLICOS | CRIATIVO 06             3
# 00 | AUTO | MIX DE PUBLICOS | CRIATIVO 05             3
# 00 | AUTO |  LAL | 1% | ENV 7D | CRIATIVO 10          2
# 00 | AUTO | LAL | 1% | ENVOLVIMENTO | LEADS GERAL     2
# 00 | AUTO | MIX DE PUBLICOS | CRIATIVO 02             1
# 00 | AUTO | LAL | 1% | ENVOLVIMENTO IG 7D             1
# {{adset.name}}                                        1
# 00 | AUTO | SEGUIDORES                                1
# 00 | AUTO | MIX DE PUBLICOS | CRIATIVO 04             1
# Name: count, dtype: int64
#
# Coluna: utm_content
# utm_content
#                                 85
# ADS_007_ANUNCIO PETRO 07        27
# NaN                             20
# ADS_008_ANUNCIO PETRO 08        18
# ADS_006_ANUNCIO PETRO 06        12
# ADS_001_ANUNCIO PETRO 01        10
# ADS_005_ANUNCIO PETRO 05         7
# ADS_011_ANUNCIO PETRO 11         6
# ADS_010_ANUNCIO PETRO 10         2
# ADS_003_ANUNCIO PETRO 03         2
# ADS_002_ANUNCIO PETRO 02         1
# {{ad.name}}                      1
# ADS_004_ANUNCIO PETRO 04         1
# AD_001_ ANUNCIO PETRO 01         1
# AD_002_ ANUNCIO PETRO 02         1
# ADS_VID_002_ANUNCIO PETRO 02     1
# Name: count, dtype: int64
